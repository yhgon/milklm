# %% [markdown]
# # milklm

# %%
# %%file model.py
import torch
import torch.nn as nn
from modules import Block
from config import ModelConfig

class Transformer(nn.Module):
    def __init__(self, config: ModelConfig, gradient_checkpointing=False):
        super().__init__()
        self.config = config
        self.gradient_checkpointing = gradient_checkpointing
        self.transformer = nn.ModuleDict({
            'wte': nn.Embedding(config.vocab_size, config.embedding_size),
            'h': nn.ModuleList([Block(config, i, gradient_checkpointing) for i in range(config.num_layers)]),
            'ln_f': nn.LayerNorm(config.embedding_size),
        })
        self.lm_head = nn.Linear(config.embedding_size, config.vocab_size, bias=False)
        self.transformer.wte.weight = self.lm_head.weight
        self.apply(self._init_weights)

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            std = 0.02
            if hasattr(module, 'NANOGPT_SCALE_INIT'):
                std *= (2 * self.config.num_layers) ** -0.5
            torch.nn.init.normal_(module.weight, mean=0.0, std=std)
            if module.bias is not None:
                torch.nn.init.zeros_(module.bias)
        elif isinstance(module, nn.Embedding):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)

    def forward(self, idx, targets=None):
        B, T = idx.size()
        assert T <= self.config.max_context_length, f"Cannot forward sequence of length {T}, block size is only {self.config.max_context_length}"
        tok_emb = self.transformer.wte(idx)
        x = tok_emb
        for block in self.transformer.h:
            x = block(x)
        x = self.transformer.ln_f(x)
        logits = self.lm_head(x)
        loss = None
        if targets is not None:
            loss = nn.functional.cross_entropy(logits.view(-1, logits.size(-1)), targets.view(-1))
        return logits, loss

# %%
# %%file utils.py
import torch
import os
import json
import numpy as np
from tiktoken import get_encoding

def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)


def load_tokens(filename, tokenizer_name='gpt-4o'):
    """Load and tokenize data from a file using tiktoken."""
    with open(filename, 'r', encoding='utf-8') as file:
        data = file.read()

    # Use tiktoken's get_encoding to obtain an encoder for GPT2
    encoder = get_encoding(tokenizer_name)
    tokens = encoder.encode(data)
    tokens = np.array(tokens, dtype=np.int32)

    return torch.tensor(tokens, dtype=torch.long)
 

def save_checkpoint(model, optimizer, model_config, train_config, data_config, epoch, loss):
    # Extract necessary details from train_config
    formatted_exp_num = f"{train_config.exp_num:03d}"
    exp_name = train_config.exp_name
    
    # Create directory structure using exp_name and formatted exp_num
    checkpoint_dir = os.path.join(exp_name, formatted_exp_num, 'checkpoints')
    os.makedirs(checkpoint_dir, exist_ok=True)

    # Save the model state
    model_path = os.path.join(checkpoint_dir, f'model_state_{epoch:04d}.pth')
    torch.save({
        'model_state_dict': model.state_dict(),
        'config': {'model_config': model_config.__dict__, 'data_config': data_config.__dict__, 'train_config': train_config.__dict__},
        'epoch': epoch,
        'loss': loss
    }, model_path)

    # Save the optimizer state
    optimizer_path = os.path.join(checkpoint_dir, f'optimizer_state_{epoch:04d}.pth')
    torch.save({
        'optimizer_state_dict': optimizer.state_dict()
    }, optimizer_path)


def load_checkpoint(exp_name, exp_num, epoch, model, optimizer):
    formatted_exp_num = f"{exp_num:03d}"
    checkpoint_dir = os.path.join(exp_name, formatted_exp_num, 'checkpoints')
    model_path = os.path.join(checkpoint_dir, f'model_state_{epoch:04d}.pth')
    optimizer_path = os.path.join(checkpoint_dir, f'optimizer_state_{epoch:04d}.pth')

    # Load model state
    model_checkpoint = torch.load(model_path)
    model.load_state_dict(model_checkpoint['model_state_dict'])

    # Load optimizer state
    optimizer_checkpoint = torch.load(optimizer_path)
    optimizer.load_state_dict(optimizer_checkpoint['optimizer_state_dict'])

    return model_checkpoint.get('epoch'), model_checkpoint.get('loss'), model_checkpoint.get('config')

# %%
# %%file eval.py
import torch
import argparse
from model import Transformer
from config import ModelConfig
from utils import load_checkpoint
from custom_data import DataLoaderLite

def evaluate():
    parser = argparse.ArgumentParser(description="Evaluate a GPT-like model.")
    parser.add_argument("--config", type=str, required=True, help="Path to config file.")
    parser.add_argument("--checkpoint", type=str, required=True, help="Path to model checkpoint.")
    args = parser.parse_args()

    config = torch.load(args.config)
    model_config = ModelConfig(**config['model_config'])

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = Transformer(model_config).to(device)
    optimizer = torch.optim.AdamW(model.parameters())
    load_checkpoint(args.checkpoint, model, optimizer)

    val_loader = DataLoaderLite(config['data_config']['batch_size'], config['data_config']['block_size'], config['data_config']['dataset_dir'], "val")
    model.eval()
    val_loader.reset()
    total_loss = 0
    with torch.no_grad():
        for _ in range(len(val_loader.tokens) // (config['data_config']['batch_size'] * config['data_config']['block_size'])):
            x, y = val_loader.next_batch()
            x, y = x.to(device), y.to(device)
            logits, loss = model(x, y)
            total_loss += loss.item()
    
    print(f"Validation Loss: {total_loss / (len(val_loader.tokens) // (config['data_config']['batch_size'] * config['data_config']['block_size']))}")

if __name__ == "__main__":
    evaluate()

# %%
# %%file modules.py 

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.checkpoint import checkpoint
import math
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import math

class CausalSelfAttention(nn.Module):
    def __init__(self, config, layer_idx):
        super().__init__()
        assert config.embedding_size % config.num_heads == 0
        self.c_attn = nn.Linear(config.embedding_size, 3 * config.embedding_size)
        self.c_proj = nn.Linear(config.embedding_size, config.embedding_size)
        self.n_head = config.num_heads
        self.n_embd = config.embedding_size
        self.layer_idx = layer_idx
        self.debug = config.debug
        self.proj_ratio = config.proj_ratio
        self.proj_ratio_min = config.proj_ratio_min
        self.num_keep_boundary_chunk = config.num_keep_boundary_chunk

        # Initialize cache for projection matrices
        self.proj_matrix_cache = {}

    def _apply_rotary_embedding(self, x, seq_len):
        dim = x.shape[-1]
        dtype = x.dtype

        theta = 10000.0
        freqs = 1.0 / (theta ** (torch.arange(0, dim, 2).float() / dim))
        freqs = torch.outer(torch.arange(seq_len), freqs).to(x.device)
        freqs_cis = torch.polar(torch.ones_like(freqs), freqs)

        if dtype not in [torch.float32, torch.float64]:
            x_temp = x.float()
        else:
            x_temp = x

        x_temp = x_temp.view(*x_temp.shape[:-1], x_temp.shape[-1] // 2, 2)
        x_temp = torch.view_as_complex(x_temp)

        x_temp = x_temp * freqs_cis
        x_rot = torch.view_as_real(x_temp).view(*x.shape[:-1], -1)
        if x.dtype != x_rot.dtype:
            x_rot = x_rot.to(dtype)

        return x_rot

    def _generate_projection_matrix(self, T, P, exponent=2):
        key = (T, P, exponent)
        if key in self.proj_matrix_cache:
            return self.proj_matrix_cache[key]

        start = 0
        end = 2595 * np.log10(1 + (T / 2) / 700.0)
        steps = np.linspace(start, end, P + 2)
        scales = 700 * (10**(steps / 2595) - 1)

        bins = np.floor((T + 1) * scales / (T / 2)).astype(int)
        bins = np.clip(bins, 0, T)  # Ensure bins are within the valid range
        basis_matrix = np.zeros((P, T))

        for p in range(1, P + 1):
            start_bin = bins[p - 1]
            mid_bin = bins[p]
            end_bin = bins[min(p + 1, len(bins) - 1)]

            for t in range(start_bin, mid_bin):
                if bins[p] - bins[p - 1] != 0:
                    basis_matrix[p - 1, t] = ((t - bins[p - 1]) / (bins[p] - bins[p - 1])) ** exponent
            for t in range(mid_bin, end_bin):
                if bins[min(p + 1, len(bins) - 1)] - bins[p] != 0:
                    basis_matrix[p - 1, t] = ((bins[min(p + 1, len(bins) - 1)] - t) / (bins[min(p + 1, len(bins) - 1)] - bins[p])) ** exponent

        self.proj_matrix_cache[key] = basis_matrix
        return basis_matrix

    def _get_boundary_tokens(self, T):
        chunk_size = T // self.proj_ratio
        num_keep = self.num_keep_boundary_chunk
        tokens_front_boundary_chunk = torch.arange(0, num_keep * chunk_size)
        tokens_last_boundary_chunk = torch.arange(T - num_keep * chunk_size, T)
        return tokens_front_boundary_chunk, tokens_last_boundary_chunk

    def _get_body_tokens(self, T):
        chunk_size = T // self.proj_ratio
        num_keep = self.num_keep_boundary_chunk
        tokens_body_chunk = torch.arange(num_keep * chunk_size, T - num_keep * chunk_size)
        return tokens_body_chunk

    def _project_tokens(self, x, tokens):
        P = tokens.numel() // self.proj_ratio
        projection_matrix = self._generate_projection_matrix(tokens.numel(), P, exponent=3)
        projection_matrix = torch.tensor(projection_matrix, dtype=torch.float32, device=x.device).T
        x_se = torch.einsum('bhtd,tp->bhpd', x[:, :, tokens], projection_matrix)
        return x_se

    def forward(self, x):
        B, T, C = x.size()
        if self.debug:
            print(f"{self.layer_idx}L - mhsa - shape of x {x.shape} input ")

        qkv = self.c_attn(x)
        if self.debug:
            print(f"{self.layer_idx}L - mhsa - shape of x {x.shape} after qkv projection")

        q, k, v = qkv.split(self.n_embd, dim=2)
        if self.debug:
            print(f"{self.layer_idx}L - mhsa - shape of Q {q.shape} after split ")
            print(f"{self.layer_idx}L - mhsa - shape of K {k.shape} after split")
            print(f"{self.layer_idx}L - mhsa - shape of V {v.shape} after split")

        k = k.view(B, T, self.n_head, C // self.n_head).transpose(1, 2)
        q = q.view(B, T, self.n_head, C // self.n_head).transpose(1, 2)
        v = v.view(B, T, self.n_head, C // self.n_head).transpose(1, 2)

        if self.debug:
            print(f"{self.layer_idx}L - mhsa - shape of Q {q.shape} after view.transpose(1,2) ")
            print(f"{self.layer_idx}L - mhsa - shape of K {k.shape} after view.transpose(1,2)")
            print(f"{self.layer_idx}L - mhsa - shape of V {v.shape} after view.transpose(1,2)")

        q = self._apply_rotary_embedding(q, T)
        k = self._apply_rotary_embedding(k, T)
        # v = self._apply_rotary_embedding(v, T)

        if self.debug:
            print(f"{self.layer_idx}L - mhsa - shape of Q {q.shape} after RoPE ")
            print(f"{self.layer_idx}L - mhsa - shape of K {k.shape} after RoPE")
            print(f"{self.layer_idx}L - mhsa - shape of V {v.shape} after RoPE")

        tokens_front_boundary_chunk, tokens_last_boundary_chunk = self._get_boundary_tokens(T)
        tokens_body_chunk = self._get_body_tokens(T)

        k_se_front_boundary = k[:, :, tokens_front_boundary_chunk]
        v_se_front_boundary = v[:, :, tokens_front_boundary_chunk]

        k_se_body = self._project_tokens(k, tokens_body_chunk)
        v_se_body = self._project_tokens(v, tokens_body_chunk)

        k_se_last_boundary = k[:, :, tokens_last_boundary_chunk]
        v_se_last_boundary = v[:, :, tokens_last_boundary_chunk]

        k_se = torch.cat([k_se_front_boundary, k_se_body, k_se_last_boundary], dim=-2)
        v_se = torch.cat([v_se_front_boundary, v_se_body, v_se_last_boundary], dim=-2)

        if self.debug:
            print(f"{self.layer_idx}L - mhsa - shape of k_se {k_se.shape} after projection")
            print(f"{self.layer_idx}L - mhsa - shape of v_se {v_se.shape} after projection")

        att = (q @ k_se.transpose(-2, -1)) * (1.0 / math.sqrt(k_se.size(-1)))
        if self.debug:
            print(f"{self.layer_idx}L - mhsa - shape of att score matrix {att.shape} after matmul")

        mask = torch.tril(torch.ones((T, k_se.size(-2)), device=x.device, dtype=torch.bool))
        if self.debug:
            print(f"{self.layer_idx}L - mhsa - shape of mask {mask.shape}")

        mask = mask[None, None, :, :]  # Add dimensions for batch and head
        if self.debug:
            print(f"{self.layer_idx}L - mhsa - shape of mask {mask.shape} after reshape")

        att = att.masked_fill(~mask[:, None, None, :], float('-inf'))

        if self.debug:
            print(f"{self.layer_idx}L - mhsa - shape of att score matrix {att.shape} after mask fill")

        #att = F.sigmoid(att)
        att =  F.softmax(att, dim=-1)
        if self.debug:
            print(f"{self.layer_idx}L - mhsa - shape of att score matrix {att.shape} after sigmoid")

        x = att @ v_se  # (B,nh,T,P) x (B,nh,P,hs) --> ( B, nh, T, hs)
        if self.debug:
            print(f"{self.layer_idx}L - mhsa - shape of x {x.shape} after matmul")

        x = x.transpose(1, 2).contiguous().view(B, T, C)
        if self.debug:
            print(f"{self.layer_idx}L - mhsa - shape of x {x.shape} after view(B,T,C)")

        x = self.c_proj(x)
        if self.debug:
            print(f"{self.layer_idx}L - mhsa - shape of x {x.shape} after out projection")
        return x

# Rest of the code remains unchanged



class MLP(nn.Module):
    def __init__(self, config, layer_idx):
        super().__init__()
        self.c_fc = nn.Linear(config.embedding_size, int(config.embedding_size * config.ffn_scale_ratio))
        self.gelu = nn.GELU()
        self.silu = F.silu
        self.c_proj = nn.Linear(int(config.embedding_size * config.ffn_scale_ratio), config.embedding_size)
        self.layer_idx = layer_idx
        self.debug = config.debug

    def forward(self, x):
        x_fc = self.c_fc(x)
        if self.debug:
            print(f"{self.layer_idx}L - mlp - shape of x_fc {x_fc.shape}")
        x_gelu = self.silu(x_fc)
        x_proj = self.c_proj(x_gelu)
        if self.debug:
            print(f"{self.layer_idx}L - mlp - shape of x_proj {x_proj.shape}")
        return x_proj

class Block(nn.Module):
    def __init__(self, config, layer_idx, gradient_checkpointing=False):
        super().__init__()
        self.ln_1 = nn.LayerNorm(config.embedding_size)
        self.attn = CausalSelfAttention(config, layer_idx)
        self.ln_2 = nn.LayerNorm(config.embedding_size)
        self.mlp = MLP(config, layer_idx)
        self.gradient_checkpointing = gradient_checkpointing

    def forward(self, x):
        if self.gradient_checkpointing and self.training:
            x = x + checkpoint(self.attn, self.ln_1(x))
            x = x + checkpoint(self.mlp, self.ln_2(x))
        else:
            x = x + self.attn(self.ln_1(x))
            x = x + self.mlp(self.ln_2(x))
        return x

# %%
# %%file config.py
from dataclasses import dataclass
import torch

@dataclass
class ModelConfig:
    embedding_size: int = 1024
    num_layers: int = 32
    num_heads: int = 32
    ffn_scale_ratio: float = 0.5
    max_context_length: int = 8192
    vocab_size: int = 200019  # 200960 for gpt-4o | 251264 for gpt2 with 1000 token buffers
    debug: bool = False  # Add debug flag
    proj_ratio_min: int = 2
    proj_ratio: int = 10
    num_keep_boundary_chunk: int = 2

 
@dataclass
class DataConfig:
    batch_size: int = 60
    block_size: int = 64
    buffer_size: int = 1 
    tokenizer_name: str = "gpt-4o"
    dataset_dir: str = "/mnt/e/jupyter/gpt2_scratch2/datasets/finewebedu/CC-MAIN-2024-10"
    truncate_limit: int = 1000000000
    shuffle_tokens: bool = False   
    mask_random: bool = False
    chunk_sizes: list = (8, 16, 32, 64 )  # Dynamic chunk sizes
    hop_size_factor: int = 4  # Factor to determine hop size from chunk size


@dataclass
class TrainConfig:
    learning_rate: float = 1e-3
    dtype: str = "bfloat16"
    optimizer_options: dict = None
    exp_name: str = "experiment"
    exp_num: int = 8
    save_interval_epoch: int = 100
    save_interval_iter: int = 20000
    print_interval_iteration: int = 1
    eval_interval_iteration: int = 250
    num_epochs: int = 200
    max_total_iters: int = 3000000
    num_warmup_steps: int = 4000
    gradient_checkpointing: bool = True
    value_clip_grad_norm: float = 0.5
    lr_step: int = 1000
    print_token_len: int = 64
# Out:
# Overwriting config.py

# %%
# %%file dummy_process.py

import torch
import torch.nn as nn
import torch.optim as optim
from model import Transformer
from config import ModelConfig
from utils import count_parameters
import pynvml
import time

def get_max_batch_size(model, device, chunk_size):
    dummy_input = torch.randint(0, model.config.vocab_size, (1, chunk_size)).to(device)
    dummy_target = torch.randint(0, model.config.vocab_size, (1, chunk_size)).to(device)

    optimizer = optim.AdamW(model.parameters(), lr=1e-3, betas=(0.9, 0.95), eps=1e-8)
    criterion = nn.CrossEntropyLoss()
    
    pynvml.nvmlInit()
    handle = pynvml.nvmlDeviceGetHandleByIndex(0)
    
    batch_size = 0
    forward_times = []
    backward_times = []
    
    while True:
        inputs = dummy_input.repeat(batch_size + 1, 1)
        targets = dummy_target.repeat(batch_size + 1, 1)
        try:
            # Forward pass
            start_forward = time.time()
            logits, loss = model(inputs, targets)
            forward_duration = (time.time() - start_forward) * 1000  # in ms

            # Backward pass
            optimizer.zero_grad()
            start_backward = time.time()
            loss.backward()
            optimizer.step()
            backward_duration = (time.time() - start_backward) * 1000  # in ms
            
            forward_times.append(forward_duration)
            backward_times.append(backward_duration)

            info = pynvml.nvmlDeviceGetMemoryInfo(handle)
            current_memory = info.used / (1024 ** 3)
            free_memory = info.free / (1024 ** 3)
            print(f"Batch Size: {batch_size + 1}, Used Memory: {current_memory:.2f} GiB, Free Memory: {free_memory:.2f} GiB, "
                  f"Forward Time: {forward_duration:.2f} ms, Backward Time: {backward_duration:.2f} ms")
            if free_memory > 1:  # Keep 1 GiB free
                batch_size += 1
            else:
                break
        except torch.cuda.OutOfMemoryError:
            break

    avg_forward_time = sum(forward_times) / len(forward_times)
    avg_backward_time = sum(backward_times) / len(backward_times)

    return batch_size, avg_forward_time, avg_backward_time

def main():
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model_config = ModelConfig()

    chunk_sizes = [8, 16, 32, 64]
    max_batch_sizes = []
    forward_times = []
    backward_times = []

    for chunk_size in chunk_sizes:
        torch.cuda.empty_cache()  # Clear the GPU cache
        model = Transformer(model_config).to(device)  # Reset model
        optimizer = optim.AdamW(model.parameters(), lr=1e-3, betas=(0.9, 0.95), eps=1e-8)  # Reset optimizer
        print(f"Detecting max batch size for chunk size: {chunk_size}")
        max_batch_size, avg_forward_time, avg_backward_time = get_max_batch_size(model, device, chunk_size)
        print(f"Max Batch Size for chunk size {chunk_size}: {max_batch_size}, "
              f"Avg Forward Time: {avg_forward_time:.2f} ms, Avg Backward Time: {avg_backward_time:.2f} ms")
        max_batch_sizes.append(max_batch_size)
        forward_times.append(avg_forward_time)
        backward_times.append(avg_backward_time)

    print(f"Detected max batch sizes: {max_batch_sizes}")
    print(f"Average Forward Times: {forward_times}")
    print(f"Average Backward Times: {backward_times}")
    torch.save(max_batch_sizes, "max_batch_sizes.pt")

if __name__ == "__main__":
    main()
# Out:
# Overwriting dummy_process.py

# %%
# !python dummy_process.py

# %%
# %%file buffer_data_loader.py

from datasets import load_dataset

class BufferDataLoader:
    def __init__(self, dataset_dir, buffer_size):
        self.dataset = load_dataset('parquet', data_files=f'{dataset_dir}/**/*.parquet', split='train', streaming=True)
        self.buffer_size = buffer_size
        self.iterator = iter(self.dataset)

    def __iter__(self):
        return self

    def __next__(self):
        buffer = []
        try:
            while len(buffer) < self.buffer_size:
                item = next(self.iterator)
                buffer.append(item['text'])
        except StopIteration:
            if not buffer:
                raise
        return buffer
# Out:
# Overwriting buffer_data_loader.py

# %%
# %%file chunk_data_loader.py

import torch
from torch.utils.data import Dataset, DataLoader
import numpy as np
from tiktoken import encoding_for_model

class ChunkDataLoader:
    def __init__(self, buffer, config, max_batch_sizes, chunk_size):
        self.buffer = buffer
        self.tokenizer = encoding_for_model(config.tokenizer_name)
        self.chunk_size = chunk_size
        self.hop_size = chunk_size // config.hop_size_factor
        self.max_batch_sizes = max_batch_sizes

        self.buffer_tokens = []
        for text in buffer:
            self.buffer_tokens.extend(self.tokenizer.encode(text))
        
        self.num_chunks = (len(self.buffer_tokens) - chunk_size) // self.hop_size + 1
        self.batch_size = max_batch_sizes[config.chunk_sizes.index(chunk_size)]
        self.current_chunk = 0

    def __iter__(self):
        self.current_chunk = 0
        return self

    def __next__(self):
        if self.current_chunk >= self.num_chunks:
            raise StopIteration
        
        start = self.current_chunk * self.hop_size
        end = start + self.chunk_size + 1

        if end > len(self.buffer_tokens):
            raise StopIteration

        chunk = self.buffer_tokens[start:end]
        inputs = torch.tensor(chunk[:-1], dtype=torch.long).unsqueeze(0)
        targets = torch.tensor(chunk[1:], dtype=torch.long).unsqueeze(0)
        
        self.current_chunk += 1

        return inputs, targets, self.current_chunk, self.num_chunks
# Out:
# Overwriting chunk_data_loader.py

# %%
# %%file train.py

import torch
import torch.nn as nn
import torch.optim as optim
import time
import argparse
from torch.optim.lr_scheduler import LambdaLR
from buffer_data_loader import BufferDataLoader
from chunk_data_loader import ChunkDataLoader
from model import Transformer
from config import ModelConfig, DataConfig, TrainConfig
from tiktoken import encoding_for_model

def train_iter(model, dataloader, optimizer, scheduler, criterion, device, total_iters, max_total_iters, model_config, train_config, data_config, tokenizer):
    model.train()
    total_loss = 0
    start_time = time.time()

    for batch_idx, (inputs, targets, chunk_idx, total_chunks) in enumerate(dataloader):
        if total_iters >= max_total_iters:
            break

        inputs, targets = inputs.to(device), targets.to(device)
        start_forward = time.time()
        logits, loss = model(inputs, targets)
        forward_duration = (time.time() - start_forward) * 1000
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        scheduler.step()
        backward_duration = (time.time() - start_forward - forward_duration / 1000) * 1000

        perplexity = torch.exp(loss).item()
        total_loss += loss.item()

        # Decode input and generated text with line breaks replaced by \n
        input_text = tokenizer.decode(inputs[0].tolist()).replace('\n', '\\n')
        gt_text = tokenizer.decode(targets[0].tolist()).replace('\n', '\\n')
        pred_text = tokenizer.decode(torch.argmax(logits[0], dim=-1).tolist()).replace('\n', '\\n')

        print(f"Iter {total_iters}/{max_total_iters}, Loss: {loss.item():.6f}, Perplexity: {perplexity:.6f}, "
              f"Chunk Size: {dataloader.chunk_size}, Batch Size: {inputs.size(0)}, "
              f"Input: {input_text[:50]}..., Target: {gt_text[:50]}..., Prediction: {pred_text[:50]}..., "
              f"Forward Time: {forward_duration:.2f} ms, Backward Time: {backward_duration:.2f} ms")

        total_iters += 1

    return total_loss / (batch_idx + 1), total_iters

def train(model, buffer_loader, optimizer, scheduler, criterion, device, model_config, train_config, data_config, max_batch_sizes):
    total_iters = 0
    tokenizer = encoding_for_model(data_config.tokenizer_name)
    max_total_iters = train_config.max_total_iters

    for buffer_idx, buffer in enumerate(buffer_loader):
        buffer_tokens = sum([len(tokenizer.encode(text)) for text in buffer])
        print(f"Buffer Index: {buffer_idx}, Total Tokens: {buffer_tokens}, Decoded Buffer: {' '.join(buffer)[:500]}...")

        for chunk_size in data_config.chunk_sizes:
            chunk_loader = ChunkDataLoader(buffer, data_config, max_batch_sizes, chunk_size)
            train_loss, total_iters = train_iter(model, chunk_loader, optimizer, scheduler, criterion, device, total_iters, max_total_iters, model_config, train_config, data_config, tokenizer)
            print(f'Total Iterations: {total_iters}/{max_total_iters} | Loss: {train_loss:.5f}')

def main():
    parser = argparse.ArgumentParser(description="Train a GPT-like model.")
    parser.add_argument("--batch_size", type=int, help="Batch size for training.")
    parser.add_argument("--block_size", type=int, help="Block size for training.")
    parser.add_argument("--learning_rate", type=float, help="Learning rate for training.")
    parser.add_argument("--max_total_iters", type=int, help="Maximum number of iterations for training.")
    parser.add_argument("--gradient_checkpointing", action='store_true', help="Enable gradient checkpointing.")
    args = parser.parse_args()

    model_config = ModelConfig()
    data_config = DataConfig()
    train_config = TrainConfig()

    if args.batch_size:
        data_config.batch_size = args.batch_size
    if args.block_size:
        data_config.block_size = args.block_size
    if args.learning_rate:
        train_config.learning_rate = args.learning_rate
    if args.max_total_iters:
        train_config.max_total_iters = args.max_total_iters
    if args.gradient_checkpointing:
        train_config.gradient_checkpointing = args.gradient_checkpointing

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    torch.manual_seed(1337)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(1337)

    model = Transformer(model_config, train_config.gradient_checkpointing).to(device)

    optimizer = optim.AdamW(model.parameters(), lr=train_config.learning_rate, betas=(0.9, 0.95), eps=1e-8)
    criterion = nn.CrossEntropyLoss()

    scheduler = LambdaLR(optimizer, lr_lambda=lambda step: min((step + 1) / train_config.num_warmup_steps, 1.0))

    buffer_loader = BufferDataLoader(data_config.dataset_dir, data_config.buffer_size)

    # Load max_batch_sizes from the precomputed file
    max_batch_sizes = torch.load("max_batch_sizes.pt")
    
    train(model, buffer_loader, optimizer, scheduler, criterion, device, model_config, train_config, data_config, max_batch_sizes)

if __name__ == "__main__":
    main()
# Out:
# Overwriting train.py

# %%
# !python dummy_process.py
# Out:
# Detecting max batch size for chunk size: 8
# Batch Size: 1, Used Memory: 7.88 GiB, Free Memory: 16.11 GiB, Forward Time: 130.52 ms, Backward Time: 276.27 ms
# Batch Size: 2, Used Memory: 8.66 GiB, Free Memory: 15.33 GiB, Forward Time: 51.56 ms, Backward Time: 49.86 ms
# Batch Size: 3, Used Memory: 8.66 GiB, Free Memory: 15.33 GiB, Forward Time: 80.40 ms, Backward Time: 65.27 ms
# Batch Size: 4, Used Memory: 9.43 GiB, Free Memory: 14.55 GiB, Forward Time: 67.21 ms, Backward Time: 48.56 ms
# Batch Size: 5, Used Memory: 9.44 GiB, Free Memory: 14.55 GiB, Forward Time: 82.57 ms, Backward Time: 56.22 ms
# Batch Size: 6, Used Memory: 9.45 GiB, Free Memory: 14.54 GiB, Forward Time: 65.81 ms, Backward Time: 46.93 ms
# Batch Size: 7, Used Memory: 9.46 GiB, Free Memory: 14.53 GiB, Forward Time: 71.66 ms, Backward Time: 50.42 ms
# Batch Size: 8, Used Memory: 9.46 GiB, Free Memory: 14.53 GiB, Forward Time: 111.77 ms, Backward Time: 57.45 ms
# Batch Size: 9, Used Memory: 9.47 GiB, Free Memory: 14.52 GiB, Forward Time: 79.97 ms, Backward Time: 48.51 ms
# Batch Size: 10, Used Memory: 9.48 GiB, Free Memory: 14.51 GiB, Forward Time: 70.42 ms, Backward Time: 47.34 ms
# Batch Size: 11, Used Memory: 9.49 GiB, Free Memory: 14.50 GiB, Forward Time: 72.18 ms, Backward Time: 66.08 ms
# Batch Size: 12, Used Memory: 9.49 GiB, Free Memory: 14.49 GiB, Forward Time: 79.26 ms, Backward Time: 58.90 ms
# Batch Size: 13, Used Memory: 9.50 GiB, Free Memory: 14.48 GiB, Forward Time: 83.14 ms, Backward Time: 112.00 ms
# Batch Size: 14, Used Memory: 9.50 GiB, Free Memory: 14.48 GiB, Forward Time: 70.78 ms, Backward Time: 51.76 ms
# Batch Size: 15, Used Memory: 9.52 GiB, Free Memory: 14.47 GiB, Forward Time: 72.96 ms, Backward Time: 55.03 ms
# Batch Size: 16, Used Memory: 9.52 GiB, Free Memory: 14.47 GiB, Forward Time: 66.48 ms, Backward Time: 54.08 ms
# Batch Size: 17, Used Memory: 9.53 GiB, Free Memory: 14.46 GiB, Forward Time: 77.75 ms, Backward Time: 61.18 ms
# Batch Size: 18, Used Memory: 9.53 GiB, Free Memory: 14.46 GiB, Forward Time: 67.38 ms, Backward Time: 52.01 ms
# Batch Size: 19, Used Memory: 9.55 GiB, Free Memory: 14.44 GiB, Forward Time: 74.55 ms, Backward Time: 49.90 ms
# Batch Size: 20, Used Memory: 9.55 GiB, Free Memory: 14.43 GiB, Forward Time: 74.72 ms, Backward Time: 80.88 ms
# Batch Size: 21, Used Memory: 9.55 GiB, Free Memory: 14.43 GiB, Forward Time: 65.01 ms, Backward Time: 71.40 ms
# Batch Size: 22, Used Memory: 9.60 GiB, Free Memory: 14.39 GiB, Forward Time: 78.85 ms, Backward Time: 48.28 ms
# Batch Size: 23, Used Memory: 9.60 GiB, Free Memory: 14.39 GiB, Forward Time: 67.82 ms, Backward Time: 53.18 ms
# Batch Size: 24, Used Memory: 9.60 GiB, Free Memory: 14.39 GiB, Forward Time: 65.08 ms, Backward Time: 52.42 ms
# Batch Size: 25, Used Memory: 9.60 GiB, Free Memory: 14.39 GiB, Forward Time: 68.74 ms, Backward Time: 59.50 ms
# Batch Size: 26, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 69.74 ms, Backward Time: 56.38 ms
# Batch Size: 27, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 71.86 ms, Backward Time: 108.29 ms
# Batch Size: 28, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 96.64 ms, Backward Time: 55.85 ms
# Batch Size: 29, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 67.45 ms, Backward Time: 84.10 ms
# Batch Size: 30, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 66.07 ms, Backward Time: 51.34 ms
# Batch Size: 31, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 67.01 ms, Backward Time: 54.20 ms
# Batch Size: 32, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 67.56 ms, Backward Time: 54.76 ms
# Batch Size: 33, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 65.82 ms, Backward Time: 64.93 ms
# Batch Size: 34, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 70.88 ms, Backward Time: 71.60 ms
# Batch Size: 35, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 72.13 ms, Backward Time: 62.61 ms
# Batch Size: 36, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 62.36 ms, Backward Time: 52.09 ms
# Batch Size: 37, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 73.30 ms, Backward Time: 82.51 ms
# Batch Size: 38, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 69.54 ms, Backward Time: 54.17 ms
# Batch Size: 39, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 85.42 ms, Backward Time: 51.22 ms
# Batch Size: 40, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 77.13 ms, Backward Time: 53.17 ms
# Batch Size: 41, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 67.55 ms, Backward Time: 80.74 ms
# Batch Size: 42, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 65.55 ms, Backward Time: 53.36 ms
# Batch Size: 43, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 72.94 ms, Backward Time: 69.65 ms
# Batch Size: 44, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 75.64 ms, Backward Time: 53.55 ms
# Batch Size: 45, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 67.86 ms, Backward Time: 89.10 ms
# Batch Size: 46, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 73.90 ms, Backward Time: 53.87 ms
# Batch Size: 47, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 82.40 ms, Backward Time: 68.28 ms
# Batch Size: 48, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 65.60 ms, Backward Time: 74.83 ms
# Batch Size: 49, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 76.89 ms, Backward Time: 58.25 ms
# Batch Size: 50, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 85.43 ms, Backward Time: 59.27 ms
# Batch Size: 51, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 75.71 ms, Backward Time: 59.48 ms
# Batch Size: 52, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 83.02 ms, Backward Time: 85.13 ms
# Batch Size: 53, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 72.94 ms, Backward Time: 64.48 ms
# Batch Size: 54, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 73.14 ms, Backward Time: 59.56 ms
# Batch Size: 55, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 67.03 ms, Backward Time: 59.21 ms
# Batch Size: 56, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 77.62 ms, Backward Time: 57.52 ms
# Batch Size: 57, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 76.49 ms, Backward Time: 67.81 ms
# Batch Size: 58, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 102.14 ms, Backward Time: 63.22 ms
# Batch Size: 59, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 64.04 ms, Backward Time: 66.08 ms
# Batch Size: 60, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 64.77 ms, Backward Time: 62.74 ms
# Batch Size: 61, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 81.36 ms, Backward Time: 90.08 ms
# Batch Size: 62, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 63.56 ms, Backward Time: 65.10 ms
# Batch Size: 63, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 69.84 ms, Backward Time: 55.22 ms
# Batch Size: 64, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 69.15 ms, Backward Time: 80.03 ms
# Batch Size: 65, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 62.96 ms, Backward Time: 70.56 ms
# Batch Size: 66, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 65.59 ms, Backward Time: 86.87 ms
# Batch Size: 67, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 73.47 ms, Backward Time: 62.58 ms
# Batch Size: 68, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 81.69 ms, Backward Time: 68.54 ms
# Batch Size: 69, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 77.50 ms, Backward Time: 60.29 ms
# Batch Size: 70, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 66.68 ms, Backward Time: 73.17 ms
# Batch Size: 71, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 85.88 ms, Backward Time: 71.13 ms
# Batch Size: 72, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 80.20 ms, Backward Time: 82.86 ms
# Batch Size: 73, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 81.84 ms, Backward Time: 57.87 ms
# Batch Size: 74, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 65.88 ms, Backward Time: 71.88 ms
# Batch Size: 75, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 77.54 ms, Backward Time: 67.18 ms
# Batch Size: 76, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 69.41 ms, Backward Time: 64.34 ms
# Batch Size: 77, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 70.23 ms, Backward Time: 65.55 ms
# Batch Size: 78, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 68.53 ms, Backward Time: 63.52 ms
# Batch Size: 79, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 77.11 ms, Backward Time: 62.54 ms
# Batch Size: 80, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 83.99 ms, Backward Time: 66.04 ms
# Batch Size: 81, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 65.93 ms, Backward Time: 75.03 ms
# Batch Size: 82, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 65.39 ms, Backward Time: 70.66 ms
# Batch Size: 83, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 70.63 ms, Backward Time: 86.10 ms
# Batch Size: 84, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 72.95 ms, Backward Time: 62.88 ms
# Batch Size: 85, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 76.22 ms, Backward Time: 92.83 ms
# Batch Size: 86, Used Memory: 10.15 GiB, Free Memory: 13.84 GiB, Forward Time: 84.02 ms, Backward Time: 79.29 ms
# Batch Size: 87, Used Memory: 10.67 GiB, Free Memory: 13.32 GiB, Forward Time: 67.85 ms, Backward Time: 83.30 ms
# Batch Size: 88, Used Memory: 11.19 GiB, Free Memory: 12.80 GiB, Forward Time: 66.58 ms, Backward Time: 87.40 ms
# Batch Size: 89, Used Memory: 11.72 GiB, Free Memory: 12.27 GiB, Forward Time: 67.17 ms, Backward Time: 94.55 ms
# Batch Size: 90, Used Memory: 12.26 GiB, Free Memory: 11.73 GiB, Forward Time: 73.02 ms, Backward Time: 95.73 ms
# Batch Size: 91, Used Memory: 12.80 GiB, Free Memory: 11.19 GiB, Forward Time: 74.04 ms, Backward Time: 76.62 ms
# Batch Size: 92, Used Memory: 13.35 GiB, Free Memory: 10.64 GiB, Forward Time: 71.72 ms, Backward Time: 73.81 ms
# Batch Size: 93, Used Memory: 13.91 GiB, Free Memory: 10.08 GiB, Forward Time: 84.92 ms, Backward Time: 75.86 ms
# Batch Size: 94, Used Memory: 14.47 GiB, Free Memory: 9.52 GiB, Forward Time: 69.72 ms, Backward Time: 107.64 ms
# Batch Size: 95, Used Memory: 15.03 GiB, Free Memory: 8.96 GiB, Forward Time: 78.63 ms, Backward Time: 73.35 ms
# Batch Size: 96, Used Memory: 15.61 GiB, Free Memory: 8.38 GiB, Forward Time: 71.89 ms, Backward Time: 85.45 ms
# Batch Size: 97, Used Memory: 16.19 GiB, Free Memory: 7.80 GiB, Forward Time: 86.90 ms, Backward Time: 130.75 ms
# Batch Size: 98, Used Memory: 16.77 GiB, Free Memory: 7.22 GiB, Forward Time: 69.01 ms, Backward Time: 84.50 ms
# Batch Size: 99, Used Memory: 17.36 GiB, Free Memory: 6.63 GiB, Forward Time: 73.21 ms, Backward Time: 90.62 ms
# Batch Size: 100, Used Memory: 17.96 GiB, Free Memory: 6.03 GiB, Forward Time: 66.21 ms, Backward Time: 77.32 ms
# Batch Size: 101, Used Memory: 18.56 GiB, Free Memory: 5.42 GiB, Forward Time: 69.04 ms, Backward Time: 91.84 ms
# Batch Size: 102, Used Memory: 19.17 GiB, Free Memory: 4.81 GiB, Forward Time: 76.61 ms, Backward Time: 92.41 ms
# Batch Size: 103, Used Memory: 19.79 GiB, Free Memory: 4.20 GiB, Forward Time: 78.65 ms, Backward Time: 81.44 ms
# Batch Size: 104, Used Memory: 21.17 GiB, Free Memory: 2.81 GiB, Forward Time: 68.80 ms, Backward Time: 105.35 ms
# Batch Size: 105, Used Memory: 21.17 GiB, Free Memory: 2.81 GiB, Forward Time: 76.89 ms, Backward Time: 81.66 ms
# Batch Size: 106, Used Memory: 21.17 GiB, Free Memory: 2.81 GiB, Forward Time: 77.96 ms, Backward Time: 90.94 ms
# Batch Size: 107, Used Memory: 21.17 GiB, Free Memory: 2.81 GiB, Forward Time: 77.14 ms, Backward Time: 94.83 ms
# Batch Size: 108, Used Memory: 21.17 GiB, Free Memory: 2.81 GiB, Forward Time: 66.41 ms, Backward Time: 92.05 ms
# Batch Size: 109, Used Memory: 21.17 GiB, Free Memory: 2.81 GiB, Forward Time: 70.57 ms, Backward Time: 98.73 ms
# Batch Size: 110, Used Memory: 21.17 GiB, Free Memory: 2.81 GiB, Forward Time: 95.18 ms, Backward Time: 86.43 ms
# Batch Size: 111, Used Memory: 21.17 GiB, Free Memory: 2.81 GiB, Forward Time: 97.18 ms, Backward Time: 78.21 ms
# Batch Size: 112, Used Memory: 21.17 GiB, Free Memory: 2.81 GiB, Forward Time: 80.91 ms, Backward Time: 84.39 ms
# Batch Size: 113, Used Memory: 21.17 GiB, Free Memory: 2.81 GiB, Forward Time: 68.85 ms, Backward Time: 93.95 ms
# Batch Size: 114, Used Memory: 21.17 GiB, Free Memory: 2.81 GiB, Forward Time: 77.64 ms, Backward Time: 96.00 ms
# Batch Size: 115, Used Memory: 21.17 GiB, Free Memory: 2.81 GiB, Forward Time: 104.36 ms, Backward Time: 74.04 ms
# Batch Size: 116, Used Memory: 21.17 GiB, Free Memory: 2.81 GiB, Forward Time: 70.85 ms, Backward Time: 88.53 ms
# Batch Size: 117, Used Memory: 21.17 GiB, Free Memory: 2.81 GiB, Forward Time: 73.48 ms, Backward Time: 73.47 ms
# Batch Size: 118, Used Memory: 21.17 GiB, Free Memory: 2.81 GiB, Forward Time: 70.19 ms, Backward Time: 92.45 ms
# Batch Size: 119, Used Memory: 21.17 GiB, Free Memory: 2.81 GiB, Forward Time: 74.92 ms, Backward Time: 74.59 ms
# Batch Size: 120, Used Memory: 21.17 GiB, Free Memory: 2.81 GiB, Forward Time: 72.01 ms, Backward Time: 88.52 ms
# Batch Size: 121, Used Memory: 21.17 GiB, Free Memory: 2.81 GiB, Forward Time: 84.24 ms, Backward Time: 104.49 ms
# Batch Size: 122, Used Memory: 21.17 GiB, Free Memory: 2.81 GiB, Forward Time: 69.56 ms, Backward Time: 84.53 ms
# Batch Size: 123, Used Memory: 21.94 GiB, Free Memory: 2.05 GiB, Forward Time: 81.11 ms, Backward Time: 80.21 ms
# Batch Size: 124, Used Memory: 21.94 GiB, Free Memory: 2.05 GiB, Forward Time: 85.48 ms, Backward Time: 75.30 ms
# Batch Size: 125, Used Memory: 21.94 GiB, Free Memory: 2.05 GiB, Forward Time: 75.62 ms, Backward Time: 80.76 ms
# Batch Size: 126, Used Memory: 21.94 GiB, Free Memory: 2.05 GiB, Forward Time: 71.52 ms, Backward Time: 81.59 ms
# Batch Size: 127, Used Memory: 21.94 GiB, Free Memory: 2.05 GiB, Forward Time: 71.26 ms, Backward Time: 79.27 ms
# Batch Size: 128, Used Memory: 21.94 GiB, Free Memory: 2.05 GiB, Forward Time: 70.20 ms, Backward Time: 77.81 ms
# Batch Size: 129, Used Memory: 23.98 GiB, Free Memory: 0.01 GiB, Forward Time: 134.06 ms, Backward Time: 1661.74 ms
# Max Batch Size for chunk size 8: 128, Avg Forward Time: 75.11 ms, Avg Backward Time: 86.13 ms
# Detecting max batch size for chunk size: 16
# Batch Size: 1, Used Memory: 6.53 GiB, Free Memory: 17.46 GiB, Forward Time: 61.89 ms, Backward Time: 144.81 ms
# Batch Size: 2, Used Memory: 9.08 GiB, Free Memory: 14.91 GiB, Forward Time: 189.77 ms, Backward Time: 67.41 ms
# Batch Size: 3, Used Memory: 9.48 GiB, Free Memory: 14.51 GiB, Forward Time: 105.57 ms, Backward Time: 59.10 ms
# Batch Size: 4, Used Memory: 9.50 GiB, Free Memory: 14.49 GiB, Forward Time: 107.95 ms, Backward Time: 119.80 ms
# Batch Size: 5, Used Memory: 9.51 GiB, Free Memory: 14.47 GiB, Forward Time: 104.46 ms, Backward Time: 79.21 ms
# Batch Size: 6, Used Memory: 9.53 GiB, Free Memory: 14.46 GiB, Forward Time: 100.23 ms, Backward Time: 74.35 ms
# Batch Size: 7, Used Memory: 9.54 GiB, Free Memory: 14.44 GiB, Forward Time: 88.98 ms, Backward Time: 68.53 ms
# Batch Size: 8, Used Memory: 9.56 GiB, Free Memory: 14.43 GiB, Forward Time: 86.94 ms, Backward Time: 60.92 ms
# Batch Size: 9, Used Memory: 9.58 GiB, Free Memory: 14.41 GiB, Forward Time: 85.77 ms, Backward Time: 65.28 ms
# Batch Size: 10, Used Memory: 9.59 GiB, Free Memory: 14.39 GiB, Forward Time: 112.04 ms, Backward Time: 104.80 ms
# Batch Size: 11, Used Memory: 9.62 GiB, Free Memory: 14.37 GiB, Forward Time: 82.37 ms, Backward Time: 83.30 ms
# Batch Size: 12, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 79.22 ms, Backward Time: 61.89 ms
# Batch Size: 13, Used Memory: 9.66 GiB, Free Memory: 14.33 GiB, Forward Time: 107.62 ms, Backward Time: 95.18 ms
# Batch Size: 14, Used Memory: 9.67 GiB, Free Memory: 14.32 GiB, Forward Time: 84.99 ms, Backward Time: 66.01 ms
# Batch Size: 15, Used Memory: 9.68 GiB, Free Memory: 14.31 GiB, Forward Time: 80.78 ms, Backward Time: 75.74 ms
# Batch Size: 16, Used Memory: 9.69 GiB, Free Memory: 14.30 GiB, Forward Time: 117.86 ms, Backward Time: 76.10 ms
# Batch Size: 17, Used Memory: 9.69 GiB, Free Memory: 14.30 GiB, Forward Time: 79.98 ms, Backward Time: 72.98 ms
# Batch Size: 18, Used Memory: 9.69 GiB, Free Memory: 14.30 GiB, Forward Time: 76.72 ms, Backward Time: 70.54 ms
# Batch Size: 19, Used Memory: 9.69 GiB, Free Memory: 14.30 GiB, Forward Time: 79.15 ms, Backward Time: 76.43 ms
# Batch Size: 20, Used Memory: 9.69 GiB, Free Memory: 14.30 GiB, Forward Time: 90.35 ms, Backward Time: 65.87 ms
# Batch Size: 21, Used Memory: 9.69 GiB, Free Memory: 14.30 GiB, Forward Time: 98.95 ms, Backward Time: 78.24 ms
# Batch Size: 22, Used Memory: 9.69 GiB, Free Memory: 14.30 GiB, Forward Time: 81.58 ms, Backward Time: 72.37 ms
# Batch Size: 23, Used Memory: 9.69 GiB, Free Memory: 14.30 GiB, Forward Time: 82.56 ms, Backward Time: 71.29 ms
# Batch Size: 24, Used Memory: 9.69 GiB, Free Memory: 14.30 GiB, Forward Time: 79.80 ms, Backward Time: 66.92 ms
# Batch Size: 25, Used Memory: 9.69 GiB, Free Memory: 14.30 GiB, Forward Time: 78.39 ms, Backward Time: 73.74 ms
# Batch Size: 26, Used Memory: 9.69 GiB, Free Memory: 14.30 GiB, Forward Time: 125.04 ms, Backward Time: 78.94 ms
# Batch Size: 27, Used Memory: 9.69 GiB, Free Memory: 14.30 GiB, Forward Time: 84.09 ms, Backward Time: 90.50 ms
# Batch Size: 28, Used Memory: 9.69 GiB, Free Memory: 14.30 GiB, Forward Time: 83.26 ms, Backward Time: 72.03 ms
# Batch Size: 29, Used Memory: 9.69 GiB, Free Memory: 14.30 GiB, Forward Time: 81.72 ms, Backward Time: 78.75 ms
# Batch Size: 30, Used Memory: 9.69 GiB, Free Memory: 14.30 GiB, Forward Time: 77.49 ms, Backward Time: 77.65 ms
# Batch Size: 31, Used Memory: 9.69 GiB, Free Memory: 14.30 GiB, Forward Time: 83.98 ms, Backward Time: 82.65 ms
# Batch Size: 32, Used Memory: 9.69 GiB, Free Memory: 14.30 GiB, Forward Time: 91.73 ms, Backward Time: 87.53 ms
# Batch Size: 33, Used Memory: 9.69 GiB, Free Memory: 14.30 GiB, Forward Time: 79.51 ms, Backward Time: 75.30 ms
# Batch Size: 34, Used Memory: 9.69 GiB, Free Memory: 14.30 GiB, Forward Time: 90.79 ms, Backward Time: 78.53 ms
# Batch Size: 35, Used Memory: 9.69 GiB, Free Memory: 14.30 GiB, Forward Time: 86.85 ms, Backward Time: 103.87 ms
# Batch Size: 36, Used Memory: 9.69 GiB, Free Memory: 14.30 GiB, Forward Time: 77.62 ms, Backward Time: 82.19 ms
# Batch Size: 37, Used Memory: 9.69 GiB, Free Memory: 14.30 GiB, Forward Time: 89.44 ms, Backward Time: 76.49 ms
# Batch Size: 38, Used Memory: 9.69 GiB, Free Memory: 14.30 GiB, Forward Time: 96.37 ms, Backward Time: 77.58 ms
# Batch Size: 39, Used Memory: 9.69 GiB, Free Memory: 14.30 GiB, Forward Time: 86.36 ms, Backward Time: 76.10 ms
# Batch Size: 40, Used Memory: 9.69 GiB, Free Memory: 14.30 GiB, Forward Time: 101.42 ms, Backward Time: 79.69 ms
# Batch Size: 41, Used Memory: 9.69 GiB, Free Memory: 14.30 GiB, Forward Time: 81.11 ms, Backward Time: 88.08 ms
# Batch Size: 42, Used Memory: 9.69 GiB, Free Memory: 14.30 GiB, Forward Time: 91.89 ms, Backward Time: 81.73 ms
# Batch Size: 43, Used Memory: 9.69 GiB, Free Memory: 14.30 GiB, Forward Time: 80.57 ms, Backward Time: 84.80 ms
# Batch Size: 44, Used Memory: 9.69 GiB, Free Memory: 14.30 GiB, Forward Time: 79.46 ms, Backward Time: 82.83 ms
# Batch Size: 45, Used Memory: 9.69 GiB, Free Memory: 14.30 GiB, Forward Time: 77.83 ms, Backward Time: 132.57 ms
# Batch Size: 46, Used Memory: 10.24 GiB, Free Memory: 13.75 GiB, Forward Time: 88.84 ms, Backward Time: 94.57 ms
# Batch Size: 47, Used Memory: 10.80 GiB, Free Memory: 13.19 GiB, Forward Time: 87.88 ms, Backward Time: 112.80 ms
# Batch Size: 48, Used Memory: 11.37 GiB, Free Memory: 12.62 GiB, Forward Time: 116.70 ms, Backward Time: 109.27 ms
# Batch Size: 49, Used Memory: 11.96 GiB, Free Memory: 12.03 GiB, Forward Time: 78.69 ms, Backward Time: 94.47 ms
# Batch Size: 50, Used Memory: 12.55 GiB, Free Memory: 11.44 GiB, Forward Time: 97.30 ms, Backward Time: 123.81 ms
# Batch Size: 51, Used Memory: 13.16 GiB, Free Memory: 10.83 GiB, Forward Time: 102.46 ms, Backward Time: 148.27 ms
# Batch Size: 52, Used Memory: 13.78 GiB, Free Memory: 10.21 GiB, Forward Time: 103.63 ms, Backward Time: 182.49 ms
# Batch Size: 53, Used Memory: 14.42 GiB, Free Memory: 9.57 GiB, Forward Time: 80.96 ms, Backward Time: 100.50 ms
# Batch Size: 54, Used Memory: 15.06 GiB, Free Memory: 8.93 GiB, Forward Time: 84.52 ms, Backward Time: 97.36 ms
# Batch Size: 55, Used Memory: 15.72 GiB, Free Memory: 8.27 GiB, Forward Time: 97.06 ms, Backward Time: 101.40 ms
# Batch Size: 56, Used Memory: 16.38 GiB, Free Memory: 7.60 GiB, Forward Time: 87.48 ms, Backward Time: 104.59 ms
# Batch Size: 57, Used Memory: 17.06 GiB, Free Memory: 6.92 GiB, Forward Time: 99.80 ms, Backward Time: 104.67 ms
# Batch Size: 58, Used Memory: 17.76 GiB, Free Memory: 6.23 GiB, Forward Time: 84.23 ms, Backward Time: 100.91 ms
# Batch Size: 59, Used Memory: 18.46 GiB, Free Memory: 5.53 GiB, Forward Time: 106.68 ms, Backward Time: 109.83 ms
# Batch Size: 60, Used Memory: 19.18 GiB, Free Memory: 4.81 GiB, Forward Time: 94.41 ms, Backward Time: 110.46 ms
# Batch Size: 61, Used Memory: 19.91 GiB, Free Memory: 4.08 GiB, Forward Time: 98.72 ms, Backward Time: 127.65 ms
# Batch Size: 62, Used Memory: 20.65 GiB, Free Memory: 3.34 GiB, Forward Time: 80.39 ms, Backward Time: 110.23 ms
# Batch Size: 63, Used Memory: 21.40 GiB, Free Memory: 2.59 GiB, Forward Time: 106.24 ms, Backward Time: 108.00 ms
# Batch Size: 64, Used Memory: 21.40 GiB, Free Memory: 2.59 GiB, Forward Time: 82.25 ms, Backward Time: 106.81 ms
# Batch Size: 65, Used Memory: 23.94 GiB, Free Memory: 0.05 GiB, Forward Time: 90.36 ms, Backward Time: 1225.90 ms
# Max Batch Size for chunk size 16: 64, Avg Forward Time: 91.68 ms, Avg Backward Time: 107.89 ms
# Detecting max batch size for chunk size: 32
# Batch Size: 1, Used Memory: 7.95 GiB, Free Memory: 16.04 GiB, Forward Time: 76.22 ms, Backward Time: 176.42 ms
# Batch Size: 2, Used Memory: 9.07 GiB, Free Memory: 14.92 GiB, Forward Time: 152.04 ms, Backward Time: 121.20 ms
# Batch Size: 3, Used Memory: 9.55 GiB, Free Memory: 14.44 GiB, Forward Time: 222.53 ms, Backward Time: 76.66 ms
# Batch Size: 4, Used Memory: 9.58 GiB, Free Memory: 14.40 GiB, Forward Time: 137.41 ms, Backward Time: 87.99 ms
# Batch Size: 5, Used Memory: 9.63 GiB, Free Memory: 14.36 GiB, Forward Time: 127.33 ms, Backward Time: 81.93 ms
# Batch Size: 6, Used Memory: 9.67 GiB, Free Memory: 14.32 GiB, Forward Time: 112.69 ms, Backward Time: 78.87 ms
# Batch Size: 7, Used Memory: 9.72 GiB, Free Memory: 14.27 GiB, Forward Time: 87.39 ms, Backward Time: 111.02 ms
# Batch Size: 8, Used Memory: 9.72 GiB, Free Memory: 14.27 GiB, Forward Time: 116.81 ms, Backward Time: 70.95 ms
# Batch Size: 9, Used Memory: 9.72 GiB, Free Memory: 14.27 GiB, Forward Time: 87.50 ms, Backward Time: 79.05 ms
# Batch Size: 10, Used Memory: 9.72 GiB, Free Memory: 14.27 GiB, Forward Time: 82.26 ms, Backward Time: 74.67 ms
# Batch Size: 11, Used Memory: 9.72 GiB, Free Memory: 14.27 GiB, Forward Time: 102.78 ms, Backward Time: 84.50 ms
# Batch Size: 12, Used Memory: 9.72 GiB, Free Memory: 14.27 GiB, Forward Time: 98.76 ms, Backward Time: 89.46 ms
# Batch Size: 13, Used Memory: 9.72 GiB, Free Memory: 14.27 GiB, Forward Time: 90.59 ms, Backward Time: 69.63 ms
# Batch Size: 14, Used Memory: 9.72 GiB, Free Memory: 14.27 GiB, Forward Time: 83.83 ms, Backward Time: 72.75 ms
# Batch Size: 15, Used Memory: 9.72 GiB, Free Memory: 14.27 GiB, Forward Time: 83.33 ms, Backward Time: 88.85 ms
# Batch Size: 16, Used Memory: 9.72 GiB, Free Memory: 14.27 GiB, Forward Time: 83.40 ms, Backward Time: 72.21 ms
# Batch Size: 17, Used Memory: 9.72 GiB, Free Memory: 14.27 GiB, Forward Time: 87.50 ms, Backward Time: 77.21 ms
# Batch Size: 18, Used Memory: 9.72 GiB, Free Memory: 14.27 GiB, Forward Time: 96.17 ms, Backward Time: 95.10 ms
# Batch Size: 19, Used Memory: 9.72 GiB, Free Memory: 14.27 GiB, Forward Time: 79.97 ms, Backward Time: 91.79 ms
# Batch Size: 20, Used Memory: 10.20 GiB, Free Memory: 13.79 GiB, Forward Time: 80.93 ms, Backward Time: 115.36 ms
# Batch Size: 21, Used Memory: 10.70 GiB, Free Memory: 13.29 GiB, Forward Time: 87.23 ms, Backward Time: 89.98 ms
# Batch Size: 22, Used Memory: 11.22 GiB, Free Memory: 12.76 GiB, Forward Time: 80.95 ms, Backward Time: 103.16 ms
# Batch Size: 23, Used Memory: 11.77 GiB, Free Memory: 12.21 GiB, Forward Time: 88.95 ms, Backward Time: 149.94 ms
# Batch Size: 24, Used Memory: 12.35 GiB, Free Memory: 11.64 GiB, Forward Time: 79.65 ms, Backward Time: 140.88 ms
# Batch Size: 25, Used Memory: 12.94 GiB, Free Memory: 11.04 GiB, Forward Time: 94.55 ms, Backward Time: 105.41 ms
# Batch Size: 26, Used Memory: 13.56 GiB, Free Memory: 10.42 GiB, Forward Time: 114.77 ms, Backward Time: 103.16 ms
# Batch Size: 27, Used Memory: 14.21 GiB, Free Memory: 9.78 GiB, Forward Time: 89.06 ms, Backward Time: 144.08 ms
# Batch Size: 28, Used Memory: 14.88 GiB, Free Memory: 9.11 GiB, Forward Time: 95.36 ms, Backward Time: 100.72 ms
# Batch Size: 29, Used Memory: 15.57 GiB, Free Memory: 8.42 GiB, Forward Time: 100.78 ms, Backward Time: 102.79 ms
# Batch Size: 30, Used Memory: 16.29 GiB, Free Memory: 7.70 GiB, Forward Time: 83.22 ms, Backward Time: 111.49 ms
# Batch Size: 31, Used Memory: 17.03 GiB, Free Memory: 6.96 GiB, Forward Time: 87.41 ms, Backward Time: 112.06 ms
# Batch Size: 32, Used Memory: 17.79 GiB, Free Memory: 6.20 GiB, Forward Time: 94.91 ms, Backward Time: 105.98 ms
# Batch Size: 33, Used Memory: 20.94 GiB, Free Memory: 3.05 GiB, Forward Time: 97.14 ms, Backward Time: 150.47 ms
# Batch Size: 34, Used Memory: 23.94 GiB, Free Memory: 0.05 GiB, Forward Time: 98.30 ms, Backward Time: 626.21 ms
# Max Batch Size for chunk size 32: 33, Avg Forward Time: 99.46 ms, Avg Backward Time: 116.53 ms
# Detecting max batch size for chunk size: 64
# Batch Size: 1, Used Memory: 7.25 GiB, Free Memory: 16.73 GiB, Forward Time: 80.20 ms, Backward Time: 118.24 ms
# Batch Size: 2, Used Memory: 9.62 GiB, Free Memory: 14.37 GiB, Forward Time: 202.12 ms, Backward Time: 119.82 ms
# Batch Size: 3, Used Memory: 9.71 GiB, Free Memory: 14.28 GiB, Forward Time: 83.22 ms, Backward Time: 63.68 ms
# Batch Size: 4, Used Memory: 9.77 GiB, Free Memory: 14.22 GiB, Forward Time: 91.26 ms, Backward Time: 62.91 ms
# Batch Size: 5, Used Memory: 9.77 GiB, Free Memory: 14.22 GiB, Forward Time: 88.75 ms, Backward Time: 88.64 ms
# Batch Size: 6, Used Memory: 9.77 GiB, Free Memory: 14.22 GiB, Forward Time: 96.64 ms, Backward Time: 67.41 ms
# Batch Size: 7, Used Memory: 9.77 GiB, Free Memory: 14.22 GiB, Forward Time: 89.44 ms, Backward Time: 75.99 ms
# Batch Size: 8, Used Memory: 9.77 GiB, Free Memory: 14.22 GiB, Forward Time: 83.21 ms, Backward Time: 85.67 ms
# Batch Size: 9, Used Memory: 9.77 GiB, Free Memory: 14.22 GiB, Forward Time: 94.12 ms, Backward Time: 85.34 ms
# Batch Size: 10, Used Memory: 10.25 GiB, Free Memory: 13.74 GiB, Forward Time: 86.59 ms, Backward Time: 89.56 ms
# Batch Size: 11, Used Memory: 10.78 GiB, Free Memory: 13.21 GiB, Forward Time: 89.86 ms, Backward Time: 98.94 ms
# Batch Size: 12, Used Memory: 11.35 GiB, Free Memory: 12.64 GiB, Forward Time: 97.22 ms, Backward Time: 163.42 ms
# Batch Size: 13, Used Memory: 11.97 GiB, Free Memory: 12.02 GiB, Forward Time: 98.15 ms, Backward Time: 101.48 ms
# Batch Size: 14, Used Memory: 13.40 GiB, Free Memory: 10.59 GiB, Forward Time: 84.84 ms, Backward Time: 107.74 ms
# Batch Size: 15, Used Memory: 14.12 GiB, Free Memory: 9.87 GiB, Forward Time: 103.27 ms, Backward Time: 106.45 ms
# Batch Size: 16, Used Memory: 14.88 GiB, Free Memory: 9.11 GiB, Forward Time: 83.63 ms, Backward Time: 112.35 ms
# Batch Size: 17, Used Memory: 18.13 GiB, Free Memory: 5.86 GiB, Forward Time: 134.60 ms, Backward Time: 149.53 ms
# Batch Size: 18, Used Memory: 21.57 GiB, Free Memory: 2.42 GiB, Forward Time: 95.37 ms, Backward Time: 157.28 ms
# Batch Size: 19, Used Memory: 23.82 GiB, Free Memory: 0.17 GiB, Forward Time: 107.27 ms, Backward Time: 2026.80 ms
# Max Batch Size for chunk size 64: 18, Avg Forward Time: 99.46 ms, Avg Backward Time: 204.28 ms
# Detected max batch sizes: [128, 64, 33, 18]
# Average Forward Times: [75.11089199273161, 91.67759235088641, 99.46261433994069, 99.459497552169]
# Average Backward Times: [86.13367043724355, 107.88638041569637, 116.52784487780403, 204.27700092917993]

# %%
# !python train.py #
# Out:
# Buffer Index: 0, Total Tokens: 985, Decoded Buffer: – Computer viruses are parasitic programs which are able to replicate themselves, attach themselves to other executables in the computer, and perform some unwanted and often malicious actions. A virus is not able to spread itself to another computers, some user actions are needed for it to infect a new computer. Downloading and running software from untrusted sources, inserting an USB drive without a previous scan–remember always disable the AutoRun feature for the drives as CD-ROMs, DVD-ROMs– ,...
# /home/ubuntu/miniconda3/envs/gguf/lib/python3.9/site-packages/torch/utils/checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# Iter 0/3000000, Loss: 12.112149, Perplexity: 182070.484375, Chunk Size: 8, Batch Size: 1, Input: – Computer viruses are parasitic programs which..., Target:  Computer viruses are parasitic programs which are..., Prediction: Diagram.lookup Matters जनताTokens_async Examineruo..., Forward Time: 155.66 ms, Backward Time: 319.27 ms
# Iter 1/3000000, Loss: 11.973177, Perplexity: 158447.250000, Chunk Size: 8, Batch Size: 1, Input:  viruses are parasitic programs which are able..., Target:  are parasitic programs which are able to..., Prediction:  Matters जनताTokens_async Examineruoso जनताendees..., Forward Time: 48.28 ms, Backward Time: 98.40 ms
# Iter 2/3000000, Loss: 11.876821, Perplexity: 143892.328125, Chunk Size: 8, Batch Size: 1, Input:  parasitic programs which are able to replicate..., Target: itic programs which are able to replicate themselv..., Prediction: Tokens_async Examineruoso जनताendees сколько.Rayca..., Forward Time: 57.24 ms, Backward Time: 102.96 ms
# Iter 3/3000000, Loss: 12.058330, Perplexity: 172530.546875, Chunk Size: 8, Batch Size: 1, Input:  programs which are able to replicate themselves,..., Target:  which are able to replicate themselves, attach..., Prediction:  Examineruoso जनता्ञान сколько.Raycast Decisioninn..., Forward Time: 49.23 ms, Backward Time: 110.26 ms
# Iter 4/3000000, Loss: 11.983751, Perplexity: 160131.609375, Chunk Size: 8, Batch Size: 1, Input:  are able to replicate themselves, attach themselv..., Target:  able to replicate themselves, attach themselves t..., Prediction:  willkommen्ञान сколько.Raycast Decisioninng south..., Forward Time: 49.64 ms, Backward Time: 100.83 ms
# Iter 5/3000000, Loss: 12.388338, Perplexity: 239986.531250, Chunk Size: 8, Batch Size: 1, Input:  to replicate themselves, attach themselves to oth..., Target:  replicate themselves, attach themselves to other ..., Prediction:  сколько.Raycast Decisioninng southwest Decision с..., Forward Time: 47.63 ms, Backward Time: 98.01 ms
# Iter 6/3000000, Loss: 12.250050, Perplexity: 208991.656250, Chunk Size: 8, Batch Size: 1, Input:  themselves, attach themselves to other executable..., Target: , attach themselves to other executables in..., Prediction:  Decisioninng southwest Decision сколькоhutżyć hol..., Forward Time: 38.80 ms, Backward Time: 99.47 ms
# Iter 7/3000000, Loss: 12.282731, Perplexity: 215934.640625, Chunk Size: 8, Batch Size: 1, Input:  attach themselves to other executables in the..., Target:  themselves to other executables in the computer..., Prediction:  southwest Decision сколькоhutżyć holderधी normali..., Forward Time: 38.49 ms, Backward Time: 142.35 ms
# Iter 8/3000000, Loss: 12.317443, Perplexity: 223561.734375, Chunk Size: 8, Batch Size: 1, Input:  to other executables in the computer,..., Target:  other executables in the computer, and..., Prediction:  сколькоhutżyć holderधी normalizeilianinng..., Forward Time: 37.84 ms, Backward Time: 89.53 ms
# Iter 9/3000000, Loss: 11.979054, Perplexity: 159381.250000, Chunk Size: 8, Batch Size: 1, Input:  executables in the computer, and perform..., Target: ables in the computer, and perform some..., Prediction: żyć holder 投稿日 normalizeilianinng STF Norris..., Forward Time: 44.95 ms, Backward Time: 132.28 ms
# Iter 10/3000000, Loss: 12.100744, Perplexity: 180005.781250, Chunk Size: 8, Batch Size: 1, Input:  in the computer, and perform some unwanted..., Target:  the computer, and perform some unwanted and..., Prediction:  投稿日 normalizeilianinng STF Norrisکا	AND..., Forward Time: 39.52 ms, Backward Time: 110.19 ms
# Iter 11/3000000, Loss: 12.263135, Perplexity: 211744.343750, Chunk Size: 8, Batch Size: 1, Input:  computer, and perform some unwanted and often..., Target: , and perform some unwanted and often malicious..., Prediction: ilianinng STF Norrisکا	AND STFقیق..., Forward Time: 45.73 ms, Backward Time: 127.67 ms
# Iter 12/3000000, Loss: 12.513183, Perplexity: 271898.093750, Chunk Size: 8, Batch Size: 1, Input:  and perform some unwanted and often malicious act..., Target:  perform some unwanted and often malicious actions..., Prediction:  STF Norrisکا	AND STFقیق pesquisadores nchekwa..., Forward Time: 39.85 ms, Backward Time: 94.36 ms
# Iter 13/3000000, Loss: 12.648877, Perplexity: 311413.562500, Chunk Size: 8, Batch Size: 1, Input:  some unwanted and often malicious actions. A..., Target:  unwanted and often malicious actions. A virus..., Prediction: کا	AND STFقیق pesquisadores nchekwatered SPA..., Forward Time: 62.86 ms, Backward Time: 113.43 ms
# Iter 14/3000000, Loss: 12.749441, Perplexity: 344359.406250, Chunk Size: 8, Batch Size: 1, Input:  and often malicious actions. A virus is..., Target:  often malicious actions. A virus is not..., Prediction:  STFقیق pesquisadores nchekwa.opengl SPA ينا 베..., Forward Time: 40.07 ms, Backward Time: 97.95 ms
# Iter 15/3000000, Loss: 12.164246, Perplexity: 191807.125000, Chunk Size: 8, Batch Size: 1, Input:  malicious actions. A virus is not able..., Target:  actions. A virus is not able to..., Prediction: 怎么领 nchekwa.opengl SPA ينا 베 sitsendees..., Forward Time: 61.67 ms, Backward Time: 114.49 ms
# Iter 16/3000000, Loss: 12.155661, Perplexity: 190167.515625, Chunk Size: 8, Batch Size: 1, Input: . A virus is not able to spread..., Target:  A virus is not able to spread itself..., Prediction: .opengl SPA ينا 베 sitsendees beschouwd argumentati..., Forward Time: 71.72 ms, Backward Time: 105.51 ms
# Iter 17/3000000, Loss: 12.062181, Perplexity: 173196.390625, Chunk Size: 8, Batch Size: 1, Input:  virus is not able to spread itself to..., Target:  is not able to spread itself to another..., Prediction:  ينا 베 sits to beschouwd argumentativemodell besch..., Forward Time: 38.23 ms, Backward Time: 120.97 ms
# Iter 18/3000000, Loss: 11.789423, Perplexity: 131850.375000, Chunk Size: 8, Batch Size: 1, Input:  not able to spread itself to another computers..., Target:  able to spread itself to another computers,..., Prediction:  sits to beschouwd argumentativemodell beschouwd é..., Forward Time: 38.77 ms, Backward Time: 112.60 ms
# Iter 19/3000000, Loss: 12.135325, Perplexity: 186339.484375, Chunk Size: 8, Batch Size: 1, Input:  to spread itself to another computers, some..., Target:  spread itself to another computers, some user..., Prediction:  Católica argumentativemodell Católica élim ujNST ..., Forward Time: 65.22 ms, Backward Time: 99.26 ms
# Iter 20/3000000, Loss: 12.076760, Perplexity: 175739.890625, Chunk Size: 8, Batch Size: 1, Input:  itself to another computers, some user actions..., Target:  to another computers, some user actions are..., Prediction: modell Católica élim ujNST freshest ი nchekwa..., Forward Time: 48.88 ms, Backward Time: 132.55 ms
# Iter 21/3000000, Loss: 12.142451, Perplexity: 187672.046875, Chunk Size: 8, Batch Size: 1, Input:  another computers, some user actions are needed..., Target:  computers, some user actions are needed for..., Prediction:  élim uj)}}" freshest ი nchekwa willkommenISK..., Forward Time: 41.47 ms, Backward Time: 111.60 ms
# Iter 22/3000000, Loss: 12.225974, Perplexity: 204020.171875, Chunk Size: 8, Batch Size: 1, Input: , some user actions are needed for it..., Target:  some user actions are needed for it to..., Prediction: )}}" freshest ი nchekwa willkommenISKAccumulatorsk..., Forward Time: 41.52 ms, Backward Time: 120.10 ms
# Iter 23/3000000, Loss: 12.195797, Perplexity: 197955.390625, Chunk Size: 8, Batch Size: 1, Input:  user actions are needed for it to infect..., Target:  actions are needed for it to infect a..., Prediction:  ი nchekwa ableISKAccumulatorൂട Católica utu..., Forward Time: 44.59 ms, Backward Time: 110.99 ms
# Iter 24/3000000, Loss: 12.107074, Perplexity: 181148.750000, Chunk Size: 8, Batch Size: 1, Input:  are needed for it to infect a new..., Target:  needed for it to infect a new computer..., Prediction:  ableISKAccumulatorൂട Católica utuécn.king..., Forward Time: 39.03 ms, Backward Time: 93.12 ms
# Iter 25/3000000, Loss: 11.961742, Perplexity: 156645.781250, Chunk Size: 8, Batch Size: 1, Input:  for it to infect a new computer...., Target:  it to infect a new computer. Download..., Prediction: Accumulatorൂട Católica utuécn.king,.opengl..., Forward Time: 38.42 ms, Backward Time: 100.57 ms
# Iter 26/3000000, Loss: 11.806558, Perplexity: 134129.046875, Chunk Size: 8, Batch Size: 1, Input:  to infect a new computer. Downloading..., Target:  infect a new computer. Downloading and..., Prediction:  Católica utuécn.king,.opengl ได้แก่Predicate..., Forward Time: 48.72 ms, Backward Time: 94.04 ms
# Iter 27/3000000, Loss: 11.749830, Perplexity: 126732.046875, Chunk Size: 8, Batch Size: 1, Input:  a new computer. Downloading and running..., Target:  new computer. Downloading and running software..., Prediction: écn.king, A ได้แก่Predicate STFNewsletter..., Forward Time: 41.61 ms, Backward Time: 91.54 ms
# Iter 28/3000000, Loss: 11.625895, Perplexity: 111959.734375, Chunk Size: 8, Batch Size: 1, Input:  computer. Downloading and running software from..., Target: . Downloading and running software from un..., Prediction: , A ได้แก่Predicate STFNewsletterальнай derr..., Forward Time: 51.24 ms, Backward Time: 97.51 ms
# Iter 29/3000000, Loss: 11.579135, Perplexity: 106845.046875, Chunk Size: 8, Batch Size: 1, Input:  Downloading and running software from untrusted..., Target: ing and running software from untrusted sources..., Prediction:  ได้แก่Predicate STFNewsletterальнай derr содержан..., Forward Time: 40.65 ms, Backward Time: 89.42 ms
# Iter 30/3000000, Loss: 11.682842, Perplexity: 118520.625000, Chunk Size: 8, Batch Size: 1, Input:  and running software from untrusted sources,..., Target:  running software from untrusted sources, insertin..., Prediction:  STFNewsletterальнай derr содержание اسلامي estanc..., Forward Time: 42.85 ms, Backward Time: 91.32 ms
# Iter 31/3000000, Loss: 11.724867, Perplexity: 123607.554688, Chunk Size: 8, Batch Size: 1, Input:  software from untrusted sources, inserting an..., Target:  from untrusted sources, inserting an USB..., Prediction: альнай derr содержание اسلامي estancia and	Zkiej..., Forward Time: 37.95 ms, Backward Time: 110.11 ms
# Iter 32/3000000, Loss: 11.971680, Perplexity: 158210.171875, Chunk Size: 8, Batch Size: 1, Input:  untrusted sources, inserting an USB drive..., Target: trusted sources, inserting an USB drive without..., Prediction:  содержание اسلامي estancia and	Zkiej Wired.Transa..., Forward Time: 37.76 ms, Backward Time: 91.61 ms
# Iter 33/3000000, Loss: 12.202406, Perplexity: 199268.000000, Chunk Size: 8, Batch Size: 1, Input:  sources, inserting an USB drive without a..., Target: , inserting an USB drive without a previous..., Prediction:  estancia and	Zkiej Wired.Transaction दिखécn..., Forward Time: 44.34 ms, Backward Time: 91.56 ms
# Iter 34/3000000, Loss: 12.393315, Perplexity: 241183.984375, Chunk Size: 8, Batch Size: 1, Input:  inserting an USB drive without a previous scan..., Target:  an USB drive without a previous scan–..., Prediction: 	Zkiej Wired additions दिखécn активноSSA..., Forward Time: 38.20 ms, Backward Time: 91.56 ms
# Iter 35/3000000, Loss: 12.633472, Perplexity: 306653.093750, Chunk Size: 8, Batch Size: 1, Input:  USB drive without a previous scan–remember..., Target:  drive without a previous scan–remember always..., Prediction:  Wired additions दिखécn активноSSAfragisticsусу..., Forward Time: 47.57 ms, Backward Time: 101.24 ms
# Iter 36/3000000, Loss: 12.390852, Perplexity: 240590.593750, Chunk Size: 8, Batch Size: 1, Input:  without a previous scan–remember always disable..., Target:  a previous scan–remember always disable the..., Prediction:  Squadronécn активноSSAfragisticsighde organisée y..., Forward Time: 38.75 ms, Backward Time: 89.84 ms
# Iter 37/3000000, Loss: 12.461949, Perplexity: 258318.703125, Chunk Size: 8, Batch Size: 1, Input:  previous scan–remember always disable the Auto..., Target:  scan–remember always disable the AutoRun..., Prediction:  активноSSAfragisticsighdeishwa yeroo computervrou..., Forward Time: 49.49 ms, Backward Time: 91.38 ms
# Iter 38/3000000, Loss: 12.422635, Perplexity: 248360.125000, Chunk Size: 8, Batch Size: 1, Input: –remember always disable the AutoRun feature..., Target: remember always disable the AutoRun feature for..., Prediction: fragisticsighdeishwa yeroo computervrouw périodeSt..., Forward Time: 39.80 ms, Backward Time: 91.17 ms
# Iter 39/3000000, Loss: 12.196757, Perplexity: 198145.593750, Chunk Size: 8, Batch Size: 1, Input:  always disable the AutoRun feature for the..., Target:  disable the AutoRun feature for the drives..., Prediction: ishwa yeroo computervrouw périodeStap it computer..., Forward Time: 41.55 ms, Backward Time: 90.62 ms
# Iter 40/3000000, Loss: 12.377359, Perplexity: 237366.203125, Chunk Size: 8, Batch Size: 1, Input:  the AutoRun feature for the drives as..., Target:  AutoRun feature for the drives as CD..., Prediction:  computervrouw périodeStap it computer stayetter..., Forward Time: 37.07 ms, Backward Time: 106.77 ms
# Iter 41/3000000, Loss: 12.026430, Perplexity: 167113.765625, Chunk Size: 8, Batch Size: 1, Input: Run feature for the drives as CD-ROM..., Target:  feature for the drives as CD-ROMs..., Prediction:  périodeStap it computer stayetter સહિત Bola..., Forward Time: 45.02 ms, Backward Time: 140.52 ms
# Iter 42/3000000, Loss: 11.918476, Perplexity: 150012.828125, Chunk Size: 8, Batch Size: 1, Input:  for the drives as CD-ROMs,..., Target:  the drives as CD-ROMs, DVD..., Prediction:  it computer stayetter સહિત Bola maatschappelijke ..., Forward Time: 60.67 ms, Backward Time: 96.01 ms
# Iter 43/3000000, Loss: 11.692295, Perplexity: 119646.289062, Chunk Size: 8, Batch Size: 1, Input:  drives as CD-ROMs, DVD-ROM..., Target:  as CD-ROMs, DVD-ROMs..., Prediction:  stayetter સહિત Bola maatschappelijke some està Bo..., Forward Time: 42.44 ms, Backward Time: 116.05 ms
# Iter 44/3000000, Loss: 11.503602, Perplexity: 99071.992188, Chunk Size: 8, Batch Size: 1, Input:  CD-ROMs, DVD-ROMs–..., Target: -ROMs, DVD-ROMs– ,..., Prediction:  સહિત Bola maatschappelijke some està Bola maatsch..., Forward Time: 62.09 ms, Backward Time: 115.09 ms
# Iter 45/3000000, Loss: 11.370460, Perplexity: 86721.710938, Chunk Size: 8, Batch Size: 1, Input: s, DVD-ROMs– , downloading..., Target: , DVD-ROMs– , downloading and..., Prediction:  maatschappelijke some està Bola maatschappelijker..., Forward Time: 38.85 ms, Backward Time: 96.84 ms
# Iter 46/3000000, Loss: 10.974335, Perplexity: 58357.007812, Chunk Size: 8, Batch Size: 1, Input:  DVD-ROMs– , downloading and running..., Target: -ROMs– , downloading and running emails..., Prediction:  estàs maatschappelijkeremember્થ Ancient running ..., Forward Time: 37.93 ms, Backward Time: 91.75 ms
# Iter 47/3000000, Loss: 11.267251, Perplexity: 78217.679688, Chunk Size: 8, Batch Size: 1, Input: s– , downloading and running emails or..., Target: – , downloading and running emails or IM..., Prediction: ,remember્થ Ancient running software Legs＠＼(^..., Forward Time: 46.98 ms, Backward Time: 96.24 ms
# Iter 48/3000000, Loss: 11.189676, Perplexity: 72379.343750, Chunk Size: 8, Batch Size: 1, Input:  , downloading and running emails or IM attachment..., Target:  downloading and running emails or IM attachments ..., Prediction:  нэг and running software Legs＠＼(^, қой..., Forward Time: 40.98 ms, Backward Time: 98.20 ms
# Iter 49/3000000, Loss: 11.174122, Perplexity: 71262.234375, Chunk Size: 8, Batch Size: 1, Input:  and running emails or IM attachments even from..., Target:  running emails or IM attachments even from known..., Prediction:  running software Legs＠＼(^, қойvergence un..., Forward Time: 52.67 ms, Backward Time: 104.69 ms
# \n..., Forward Time: 37.48 ms, Backward Time: 91.77 ms9219, Chunk Size: 8, Batch Size: 1, Input:  emails or IM attachments even from known persons..., Target:  or IM attachments even from known persons,..., Prediction:  Legs＠＼(^, қойvergence un to ;
# \n some væ..., Forward Time: 45.16 ms, Backward Time: 90.35 msunk Size: 8, Batch Size: 1, Input:  IM attachments even from known persons, can..., Target:  attachments even from known persons, can put..., Prediction: , қойvergence un to ;
# Iter 52/3000000, Loss: 11.279674, Perplexity: 79195.406250, Chunk Size: 8, Batch Size: 1, Input:  even from known persons, can put you..., Target:  from known persons, can put you in..., Prediction: vergence un to, some væ Download,..., Forward Time: 39.90 ms, Backward Time: 86.26 ms
# Iter 53/3000000, Loss: 11.125237, Perplexity: 67862.335938, Chunk Size: 8, Batch Size: 1, Input:  known persons, can put you in the..., Target:  persons, can put you in the nasty..., Prediction:  and, some væ Download, the drives..., Forward Time: 40.99 ms, Backward Time: 103.43 ms
# Iter 54/3000000, Loss: 11.512955, Perplexity: 100002.929688, Chunk Size: 8, Batch Size: 1, Input: , can put you in the nasty situation..., Target:  can put you in the nasty situation to..., Prediction:  and væ Download, the drives,律师..., Forward Time: 37.72 ms, Backward Time: 95.78 ms
# Iter 55/3000000, Loss: 11.583208, Perplexity: 107281.132812, Chunk Size: 8, Batch Size: 1, Input:  put you in the nasty situation to have..., Target:  you in the nasty situation to have an..., Prediction:  Download, the drives,律师 infect 연결..., Forward Time: 37.31 ms, Backward Time: 86.73 ms
# Iter 56/3000000, Loss: 11.644645, Perplexity: 114078.804688, Chunk Size: 8, Batch Size: 1, Input:  in the nasty situation to have an infected..., Target:  the nasty situation to have an infected computer..., Prediction:  the drives,律师 infect, USB and..., Forward Time: 48.17 ms, Backward Time: 111.61 ms
# Iter 57/3000000, Loss: 11.398760, Perplexity: 89211.015625, Chunk Size: 8, Batch Size: 1, Input:  nasty situation to have an infected computer...., Target:  situation to have an infected computer. Always..., Prediction: ,律师 infect, USB and, Download..., Forward Time: 40.75 ms, Backward Time: 86.87 ms
# Iter 58/3000000, Loss: 11.628620, Perplexity: 112265.304688, Chunk Size: 8, Batch Size: 1, Input:  to have an infected computer. Always when..., Target:  have an infected computer. Always when you..., Prediction:  infect, USB and, Download permitemidhi..., Forward Time: 40.67 ms, Backward Time: 94.57 ms
# Iter 59/3000000, Loss: 11.540890, Perplexity: 102835.890625, Chunk Size: 8, Batch Size: 1, Input:  an infected computer. Always when you deal..., Target:  infected computer. Always when you deal with..., Prediction:  USB and, Download permitemidhi,CES..., Forward Time: 49.12 ms, Backward Time: 86.88 ms
# Iter 60/3000000, Loss: 11.420399, Perplexity: 91162.476562, Chunk Size: 8, Batch Size: 1, Input:  computer. Always when you deal with these..., Target: . Always when you deal with these situations..., Prediction: . Download permitemidhi,CESs,..., Forward Time: 40.26 ms, Backward Time: 93.16 ms
# Iter 61/3000000, Loss: 11.637486, Perplexity: 113265.109375, Chunk Size: 8, Batch Size: 1, Input:  Always when you deal with these situations and..., Target:  when you deal with these situations and to..., Prediction: 律师idhi, tos,, running..., Forward Time: 37.32 ms, Backward Time: 99.64 ms
# Iter 62/3000000, Loss: 11.435788, Perplexity: 92576.273438, Chunk Size: 8, Batch Size: 1, Input:  you deal with these situations and to prevent..., Target:  deal with these situations and to prevent compute..., Prediction: , tos,, running infect,..., Forward Time: 44.35 ms, Backward Time: 106.87 ms
# Iter 63/3000000, Loss: 10.658948, Perplexity: 42571.824219, Chunk Size: 8, Batch Size: 1, Input:  with these situations and to prevent computer inf..., Target:  these situations and to prevent computer infectio..., Prediction: s,, running infect,.,..., Forward Time: 45.53 ms, Backward Time: 100.42 ms
# Iter 64/3000000, Loss: 10.661178, Perplexity: 42666.851562, Chunk Size: 8, Batch Size: 1, Input:  situations and to prevent computer infections, sc..., Target:  and to prevent computer infections, scan before..., Prediction: , running infect,., and–..., Forward Time: 38.21 ms, Backward Time: 98.64 ms
# Iter 65/3000000, Loss: 10.831853, Perplexity: 50607.394531, Chunk Size: 8, Batch Size: 1, Input:  to prevent computer infections, scan before to..., Target:  prevent computer infections, scan before to run..., Prediction:  infect,., and–, infect..., Forward Time: 40.84 ms, Backward Time: 94.60 ms
# Iter 66/3000000, Loss: 11.086628, Perplexity: 65292.207031, Chunk Size: 8, Batch Size: 1, Input:  computer infections, scan before to run.\n..., Target:  infections, scan before to run.\nThe..., Prediction: ., and–, infect,,..., Forward Time: 61.09 ms, Backward Time: 101.47 ms
# Iter 67/3000000, Loss: 11.720600, Perplexity: 123081.273438, Chunk Size: 8, Batch Size: 1, Input: , scan before to run.\nThe best..., Target:  scan before to run.\nThe best scanners..., Prediction:  and–, infect,, to,..., Forward Time: 42.06 ms, Backward Time: 104.44 ms
# Iter 68/3000000, Loss: 11.430035, Perplexity: 92045.164062, Chunk Size: 8, Batch Size: 1, Input:  before to run.\nThe best scanners in..., Target:  to run.\nThe best scanners in my..., Prediction: , infect,, to,, the..., Forward Time: 44.97 ms, Backward Time: 104.16 ms
# Iter 69/3000000, Loss: 11.702387, Perplexity: 120859.843750, Chunk Size: 8, Batch Size: 1, Input:  run.\nThe best scanners in my opinion..., Target: .\nThe best scanners in my opinion are..., Prediction: ,, to to, the,,..., Forward Time: 52.84 ms, Backward Time: 112.19 ms
# Iter 70/3000000, Loss: 11.716209, Perplexity: 122542.031250, Chunk Size: 8, Batch Size: 1, Input: The best scanners in my opinion are multi..., Target:  best scanners in my opinion are multi-engine..., Prediction:  to to, the,, to to..., Forward Time: 39.56 ms, Backward Time: 109.03 ms
# Iter 71/3000000, Loss: 11.793640, Perplexity: 132407.578125, Chunk Size: 8, Batch Size: 1, Input:  scanners in my opinion are multi-engine online..., Target:  in my opinion are multi-engine online scanners..., Prediction: , the,, to to to,..., Forward Time: 46.01 ms, Backward Time: 97.12 ms
# Iter 72/3000000, Loss: 12.102230, Perplexity: 180273.437500, Chunk Size: 8, Batch Size: 1, Input:  my opinion are multi-engine online scanners like..., Target:  opinion are multi-engine online scanners like vir..., Prediction: ,, to to to,, to..., Forward Time: 38.91 ms, Backward Time: 95.99 ms
# Iter 73/3000000, Loss: 12.147478, Perplexity: 188617.828125, Chunk Size: 8, Batch Size: 1, Input:  are multi-engine online scanners like virust..., Target:  multi-engine online scanners like virustotal..., Prediction:  to to to,, to to,..., Forward Time: 38.02 ms, Backward Time: 112.82 ms
# Iter 74/3000000, Loss: 11.867596, Perplexity: 142571.031250, Chunk Size: 8, Batch Size: 1, Input: -engine online scanners like virustotal.com..., Target:  online scanners like virustotal.com or..., Prediction:  to, in to to, to,..., Forward Time: 36.36 ms, Backward Time: 95.94 ms
# Iter 75/3000000, Loss: 11.797224, Perplexity: 132882.968750, Chunk Size: 8, Batch Size: 1, Input:  scanners like virustotal.com or nov..., Target:  like virustotal.com or novir..., Prediction:  in to to, to, to to..., Forward Time: 42.81 ms, Backward Time: 114.65 ms
# Iter 76/3000000, Loss: 11.761739, Perplexity: 128250.257812, Chunk Size: 8, Batch Size: 1, Input:  virustotal.com or novirust..., Target: ustotal.com or novirusth..., Prediction:  to, to, to to to,..., Forward Time: 47.40 ms, Backward Time: 99.09 ms
# Iter 77/3000000, Loss: 11.753435, Perplexity: 127189.726562, Chunk Size: 8, Batch Size: 1, Input: otal.com or novirusthanks..., Target: .com or novirusthanks.org..., Prediction:  to, to to to, to to..., Forward Time: 37.69 ms, Backward Time: 105.85 ms
# Iter 78/3000000, Loss: 11.908139, Perplexity: 148470.156250, Chunk Size: 8, Batch Size: 1, Input:  or novirusthanks.org...., Target:  novirusthanks.org. The..., Prediction:  to to to, to to to Always..., Forward Time: 40.20 ms, Backward Time: 96.08 ms
# Iter 79/3000000, Loss: 11.902709, Perplexity: 147666.109375, Chunk Size: 8, Batch Size: 1, Input: irusthanks.org. The links..., Target: usthanks.org. The links of..., Prediction:  to to to to to Always, to..., Forward Time: 38.59 ms, Backward Time: 118.17 ms
# Iter 80/3000000, Loss: 11.462250, Perplexity: 95058.687500, Chunk Size: 8, Batch Size: 1, Input: hanks.org. The links of these..., Target: anks.org. The links of these scanners..., Prediction:  to to to Always, to to situations..., Forward Time: 39.34 ms, Backward Time: 105.10 ms
# Iter 81/3000000, Loss: 10.916470, Perplexity: 55076.015625, Chunk Size: 8, Batch Size: 1, Input: .org. The links of these scanners and..., Target: . The links of these scanners and many..., Prediction:  to Always, to to situations in to..., Forward Time: 41.86 ms, Backward Time: 111.34 ms
# Iter 82/3000000, Loss: 10.840791, Perplexity: 51061.742188, Chunk Size: 8, Batch Size: 1, Input:  The links of these scanners and many more..., Target:  links of these scanners and many more are..., Prediction: , to to situations in to to to..., Forward Time: 38.02 ms, Backward Time: 116.31 ms
# Iter 83/3000000, Loss: 10.482419, Perplexity: 35682.621094, Chunk Size: 8, Batch Size: 1, Input:  of these scanners and many more are on..., Target:  these scanners and many more are on the..., Prediction:  to situations in to to to multi to..., Forward Time: 41.85 ms, Backward Time: 105.83 ms
# Iter 84/3000000, Loss: 10.992339, Perplexity: 59417.207031, Chunk Size: 8, Batch Size: 1, Input:  scanners and many more are on the home..., Target:  and many more are on the home page..., Prediction:  in to to to multi to nasty to..., Forward Time: 51.60 ms, Backward Time: 91.05 ms
# Iter 85/3000000, Loss: 10.684254, Perplexity: 43662.882812, Chunk Size: 8, Batch Size: 1, Input:  many more are on the home page.\n..., Target:  more are on the home page.\nThe..., Prediction:  to to multi to nasty to toThe..., Forward Time: 45.35 ms, Backward Time: 97.38 ms
# Iter 86/3000000, Loss: 10.831717, Perplexity: 50600.492188, Chunk Size: 8, Batch Size: 1, Input:  are on the home page.\nThe main..., Target:  on the home page.\nThe main three..., Prediction:  multi to nasty to andThe best to..., Forward Time: 37.86 ms, Backward Time: 98.54 ms
# Iter 87/3000000, Loss: 11.256516, Perplexity: 77382.539062, Chunk Size: 8, Batch Size: 1, Input:  the home page.\nThe main three features..., Target:  home page.\nThe main three features of..., Prediction:  nasty to andThe best to to,..., Forward Time: 37.39 ms, Backward Time: 102.53 ms
# Iter 88/3000000, Loss: 10.766333, Perplexity: 47397.871094, Chunk Size: 8, Batch Size: 1, Input:  page.\nThe main three features of a..., Target: .\nThe main three features of a virus..., Prediction:  andThe best to and, these to..., Forward Time: 39.29 ms, Backward Time: 122.17 ms
# Iter 89/3000000, Loss: 11.137407, Perplexity: 68693.320312, Chunk Size: 8, Batch Size: 1, Input: The main three features of a virus are..., Target:  main three features of a virus are :\n..., Prediction:  best to the, these to and multi..., Forward Time: 47.69 ms, Backward Time: 118.99 ms
# Iter 90/3000000, Loss: 10.462204, Perplexity: 34968.535156, Chunk Size: 8, Batch Size: 1, Input:  three features of a virus are :\n–..., Target:  features of a virus are :\n– the..., Prediction:  the, these to scanners multi to and..., Forward Time: 37.66 ms, Backward Time: 98.19 ms
# Iter 91/3000000, Loss: 10.477895, Perplexity: 35521.550781, Chunk Size: 8, Batch Size: 1, Input:  of a virus are :\n– the replication..., Target:  a virus are :\n– the replication mechanism..., Prediction:  these to scanners multi to and nasty to..., Forward Time: 42.36 ms, Backward Time: 97.02 ms
# Iter 92/3000000, Loss: 10.281680, Perplexity: 29192.878906, Chunk Size: 8, Batch Size: 1, Input:  virus are :\n– the replication mechanism search..., Target:  are :\n– the replication mechanism search and..., Prediction:  are multi to the nasty to,,..., Forward Time: 39.05 ms, Backward Time: 131.64 ms
# Iter 93/3000000, Loss: 10.486519, Perplexity: 35829.210938, Chunk Size: 8, Batch Size: 1, Input:  :\n– the replication mechanism search and find..., Target: – the replication mechanism search and find other..., Prediction:  to the nasty and,, to and..., Forward Time: 44.63 ms, Backward Time: 133.60 ms
# Iter 94/3000000, Loss: 11.165418, Perplexity: 70644.656250, Chunk Size: 8, Batch Size: 1, Input:  the replication mechanism search and find other e..., Target:  replication mechanism search and find other execu..., Prediction:  nasty the,, to and to and..., Forward Time: 42.10 ms, Backward Time: 113.31 ms
# Iter 95/3000000, Loss: 10.984967, Perplexity: 58980.800781, Chunk Size: 8, Batch Size: 1, Input:  mechanism search and find other executable files ..., Target:  search and find other executable files in your..., Prediction:  the and to and to and are the..., Forward Time: 41.64 ms, Backward Time: 131.30 ms
# Iter 96/3000000, Loss: 10.785775, Perplexity: 48328.425781, Chunk Size: 8, Batch Size: 1, Input:  and find other executable files in your computer..., Target:  find other executable files in your computer,..., Prediction:  to and and and are the the...., Forward Time: 39.05 ms, Backward Time: 87.83 ms
# Iter 97/3000000, Loss: 11.075653, Perplexity: 64579.554688, Chunk Size: 8, Batch Size: 1, Input:  other executable files in your computer, check..., Target:  executable files in your computer, check if..., Prediction:  and and are the the. and and..., Forward Time: 39.02 ms, Backward Time: 145.68 ms
# Iter 98/3000000, Loss: 10.478189, Perplexity: 35531.984375, Chunk Size: 8, Batch Size: 1, Input:  files in your computer, check if the..., Target:  in your computer, check if the files..., Prediction:  are the the. and and the the..., Forward Time: 49.33 ms, Backward Time: 95.45 ms
# Iter 99/3000000, Loss: 9.963793, Perplexity: 21243.212891, Chunk Size: 8, Batch Size: 1, Input:  your computer, check if the files are..., Target:  computer, check if the files are already..., Prediction:  the. and and the the are multi..., Forward Time: 46.14 ms, Backward Time: 118.39 ms
# Iter 100/3000000, Loss: 10.356126, Perplexity: 31449.105469, Chunk Size: 8, Batch Size: 1, Input: , check if the files are already infected..., Target:  check if the files are already infected–..., Prediction:  and and the the are multi and computer..., Forward Time: 43.21 ms, Backward Time: 109.34 ms
# Iter 101/3000000, Loss: 10.253814, Perplexity: 28390.611328, Chunk Size: 8, Batch Size: 1, Input:  if the files are already infected–it..., Target:  the files are already infected–it has..., Prediction:  the the are multi and computer the the..., Forward Time: 45.45 ms, Backward Time: 109.93 ms
# Iter 102/3000000, Loss: 10.655548, Perplexity: 42427.335938, Chunk Size: 8, Batch Size: 1, Input:  files are already infected–it has a..., Target:  are already infected–it has a special..., Prediction:  are multi and computer the the the virus..., Forward Time: 58.24 ms, Backward Time: 92.58 ms
# Iter 103/3000000, Loss: 11.097247, Perplexity: 65989.250000, Chunk Size: 8, Batch Size: 1, Input:  already infected–it has a special mechanism..., Target:  infected–it has a special mechanism for..., Prediction:  and computer the the the virus the the..., Forward Time: 48.54 ms, Backward Time: 96.03 ms
# Iter 104/3000000, Loss: 11.029482, Perplexity: 61665.628906, Chunk Size: 8, Batch Size: 1, Input: –it has a special mechanism for that..., Target: it has a special mechanism for that and..., Prediction:  the the the virus the the the the..., Forward Time: 36.86 ms, Backward Time: 133.11 ms
# Iter 105/3000000, Loss: 9.681482, Perplexity: 16018.223633, Chunk Size: 8, Batch Size: 1, Input:  has a special mechanism for that and if..., Target:  a special mechanism for that and if the..., Prediction:  the virus the the the the to the..., Forward Time: 45.55 ms, Backward Time: 146.55 ms
# Iter 106/3000000, Loss: 10.106520, Perplexity: 24502.236328, Chunk Size: 8, Batch Size: 1, Input:  special mechanism for that and if the file..., Target:  mechanism for that and if the file is..., Prediction:  the the the the to the the the..., Forward Time: 38.21 ms, Backward Time: 96.89 ms
# Iter 107/3000000, Loss: 10.354919, Perplexity: 31411.187500, Chunk Size: 8, Batch Size: 1, Input:  for that and if the file is clean..., Target:  that and if the file is clean then..., Prediction:  the the to the the the the the..., Forward Time: 63.37 ms, Backward Time: 110.59 ms
# Iter 108/3000000, Loss: 10.873328, Perplexity: 52750.484375, Chunk Size: 8, Batch Size: 1, Input:  and if the file is clean then append..., Target:  if the file is clean then append itself..., Prediction:  and the the the the the the the..., Forward Time: 61.89 ms, Backward Time: 133.00 ms
# Iter 109/3000000, Loss: 10.719121, Perplexity: 45212.140625, Chunk Size: 8, Batch Size: 1, Input:  the file is clean then append itself to..., Target:  file is clean then append itself to the..., Prediction:  the the the the the the the and..., Forward Time: 40.54 ms, Backward Time: 118.68 ms
# Iter 110/3000000, Loss: 10.113954, Perplexity: 24685.062500, Chunk Size: 8, Batch Size: 1, Input:  is clean then append itself to the file..., Target:  clean then append itself to the file...., Prediction:  the the the the the the the the..., Forward Time: 46.78 ms, Backward Time: 95.99 ms
# Iter 111/3000000, Loss: 9.897326, Perplexity: 19877.138672, Chunk Size: 8, Batch Size: 1, Input:  then append itself to the file. It..., Target:  append itself to the file. It can..., Prediction:  the the the the the the the the..., Forward Time: 47.50 ms, Backward Time: 108.05 ms
# Iter 112/3000000, Loss: 9.466305, Perplexity: 12917.067383, Chunk Size: 8, Batch Size: 1, Input:  itself to the file. It can append..., Target:  to the file. It can append to..., Prediction:  the the the the the the the the..., Forward Time: 40.29 ms, Backward Time: 102.56 ms
# Iter 113/3000000, Loss: 9.779435, Perplexity: 17666.671875, Chunk Size: 8, Batch Size: 1, Input:  the file. It can append to the..., Target:  file. It can append to the front..., Prediction:  the the the the the the the the..., Forward Time: 48.65 ms, Backward Time: 90.30 ms
# Iter 114/3000000, Loss: 9.763745, Perplexity: 17391.648438, Chunk Size: 8, Batch Size: 1, Input: . It can append to the front,..., Target:  It can append to the front, middle..., Prediction:  the the the the the the the and..., Forward Time: 51.37 ms, Backward Time: 115.90 ms
# Iter 115/3000000, Loss: 9.506526, Perplexity: 13447.198242, Chunk Size: 8, Batch Size: 1, Input:  can append to the front, middle or..., Target:  append to the front, middle or end..., Prediction:  the the the the the and the and..., Forward Time: 47.66 ms, Backward Time: 112.16 ms
# Iter 116/3000000, Loss: 8.904835, Perplexity: 7367.507812, Chunk Size: 8, Batch Size: 1, Input:  to the front, middle or end of..., Target:  the front, middle or end of the..., Prediction:  the the the and the the the a..., Forward Time: 47.79 ms, Backward Time: 102.01 ms
# Iter 117/3000000, Loss: 9.503574, Perplexity: 13407.565430, Chunk Size: 8, Batch Size: 1, Input:  front, middle or end of the executable..., Target: , middle or end of the executable file..., Prediction:  the and the the the a the and..., Forward Time: 43.70 ms, Backward Time: 106.25 ms
# Iter 118/3000000, Loss: 9.629364, Perplexity: 15204.762695, Chunk Size: 8, Batch Size: 1, Input:  middle or end of the executable file thus..., Target:  or end of the executable file thus changing..., Prediction:  the the the a the and the the..., Forward Time: 45.88 ms, Backward Time: 97.07 ms
# Iter 119/3000000, Loss: 8.038643, Perplexity: 3098.405518, Chunk Size: 8, Batch Size: 1, Input:  end of the executable file thus changing the..., Target:  of the executable file thus changing the file..., Prediction:  the the the and the the the the..., Forward Time: 43.43 ms, Backward Time: 105.98 ms
# Iter 120/3000000, Loss: 8.661781, Perplexity: 5777.817871, Chunk Size: 8, Batch Size: 1, Input:  the executable file thus changing the file size..., Target:  executable file thus changing the file size...., Prediction:  the and the the the the the the..., Forward Time: 52.87 ms, Backward Time: 97.23 ms
# Iter 121/3000000, Loss: 8.958586, Perplexity: 7774.354492, Chunk Size: 8, Batch Size: 1, Input:  file thus changing the file size. This..., Target:  thus changing the file size. This is..., Prediction:  the the the the the the the the..., Forward Time: 47.41 ms, Backward Time: 109.01 ms
# Iter 122/3000000, Loss: 8.034551, Perplexity: 3085.751953, Chunk Size: 8, Batch Size: 1, Input:  changing the file size. This is also..., Target:  the file size. This is also the..., Prediction:  the the the the the the the the..., Forward Time: 44.39 ms, Backward Time: 97.89 ms
# Iter 123/3000000, Loss: 10.009763, Perplexity: 22242.556641, Chunk Size: 8, Batch Size: 1, Input:  file size. This is also the reason..., Target:  size. This is also the reason why..., Prediction:  the the the the the the file the..., Forward Time: 36.74 ms, Backward Time: 149.81 ms
# Iter 124/3000000, Loss: 9.319058, Perplexity: 11148.479492, Chunk Size: 8, Batch Size: 1, Input: . This is also the reason why the..., Target:  This is also the reason why the number..., Prediction:  the the the the file the the file..., Forward Time: 38.84 ms, Backward Time: 102.68 ms
# Iter 125/3000000, Loss: 8.987155, Perplexity: 7999.665039, Chunk Size: 8, Batch Size: 1, Input:  is also the reason why the number of..., Target:  also the reason why the number of new..., Prediction:  the the file the the file the the..., Forward Time: 40.37 ms, Backward Time: 104.44 ms
# Iter 126/3000000, Loss: 10.058561, Perplexity: 23354.882812, Chunk Size: 8, Batch Size: 1, Input:  the reason why the number of new created..., Target:  reason why the number of new created viruses..., Prediction:  file the the file the the the the..., Forward Time: 40.42 ms, Backward Time: 102.53 ms
# Iter 127/3000000, Loss: 9.866659, Perplexity: 19276.830078, Chunk Size: 8, Batch Size: 1, Input:  why the number of new created viruses decreased..., Target:  the number of new created viruses decreased in..., Prediction:  the file the the the the the the..., Forward Time: 41.70 ms, Backward Time: 89.75 ms
# Iter 128/3000000, Loss: 9.826745, Perplexity: 18522.564453, Chunk Size: 8, Batch Size: 1, Input:  number of new created viruses decreased in the..., Target:  of new created viruses decreased in the last..., Prediction:  the the the the the the the file..., Forward Time: 41.44 ms, Backward Time: 90.59 ms
# Iter 129/3000000, Loss: 9.933345, Perplexity: 20606.150391, Chunk Size: 8, Batch Size: 1, Input:  new created viruses decreased in the last years..., Target:  created viruses decreased in the last years,..., Prediction:  the the the the the file the the..., Forward Time: 50.27 ms, Backward Time: 104.60 ms
# Iter 130/3000000, Loss: 8.921436, Perplexity: 7490.841309, Chunk Size: 8, Batch Size: 1, Input:  viruses decreased in the last years, the..., Target:  decreased in the last years, the Anti..., Prediction:  the the the file the the the file..., Forward Time: 49.53 ms, Backward Time: 108.61 ms
# Iter 131/3000000, Loss: 9.361284, Perplexity: 11629.314453, Chunk Size: 8, Batch Size: 1, Input:  in the last years, the AntiVir..., Target:  the last years, the AntiViruses..., Prediction:  the file the the the file the the..., Forward Time: 41.30 ms, Backward Time: 114.83 ms
# Iter 132/3000000, Loss: 9.605913, Perplexity: 14852.346680, Chunk Size: 8, Batch Size: 1, Input:  last years, the AntiViruses has..., Target:  years, the AntiViruses has a..., Prediction:  the the the file the the the the..., Forward Time: 57.73 ms, Backward Time: 105.12 ms
# Iter 133/3000000, Loss: 9.899375, Perplexity: 19917.916016, Chunk Size: 8, Batch Size: 1, Input: , the AntiViruses has a very..., Target:  the AntiViruses has a very simple..., Prediction:  the file the the the the the the..., Forward Time: 48.20 ms, Backward Time: 109.59 ms
# Iter 134/3000000, Loss: 9.928635, Perplexity: 20509.318359, Chunk Size: 8, Batch Size: 1, Input:  AntiViruses has a very simple mechanism..., Target: Viruses has a very simple mechanism for..., Prediction:  the the the the the the the the..., Forward Time: 40.27 ms, Backward Time: 111.43 ms
# Iter 135/3000000, Loss: 9.749840, Perplexity: 17151.480469, Chunk Size: 8, Batch Size: 1, Input: uses has a very simple mechanism for “..., Target:  has a very simple mechanism for “checking..., Prediction:  the the the the the the the the..., Forward Time: 40.69 ms, Backward Time: 101.16 ms
# Iter 136/3000000, Loss: 10.307456, Perplexity: 29955.132812, Chunk Size: 8, Batch Size: 1, Input:  a very simple mechanism for “checking and..., Target:  very simple mechanism for “checking and compare..., Prediction:  the the the the the the the the..., Forward Time: 54.34 ms, Backward Time: 98.95 ms
# Iter 137/3000000, Loss: 9.298389, Perplexity: 10920.416992, Chunk Size: 8, Batch Size: 1, Input:  simple mechanism for “checking and compare”..., Target:  mechanism for “checking and compare” the..., Prediction:  the the the the the the the the..., Forward Time: 39.35 ms, Backward Time: 113.78 ms
# Iter 138/3000000, Loss: 10.165609, Perplexity: 25993.695312, Chunk Size: 8, Batch Size: 1, Input:  for “checking and compare” the files..., Target:  “checking and compare” the files size..., Prediction:  the the the the the the file are..., Forward Time: 38.64 ms, Backward Time: 109.20 ms
# Iter 139/3000000, Loss: 10.458063, Perplexity: 34824.039062, Chunk Size: 8, Batch Size: 1, Input: checking and compare” the files size –..., Target:  and compare” the files size –checks..., Prediction:  the the the the file are. the..., Forward Time: 42.04 ms, Backward Time: 106.26 ms
# Iter 140/3000000, Loss: 10.872746, Perplexity: 52719.753906, Chunk Size: 8, Batch Size: 1, Input:  compare” the files size –checksums..., Target: ” the files size –checksums at..., Prediction:  the the file are. the the the..., Forward Time: 40.88 ms, Backward Time: 116.02 ms
# Iter 141/3000000, Loss: 12.024094, Perplexity: 166723.765625, Chunk Size: 8, Batch Size: 1, Input:  the files size –checksums at different..., Target:  files size –checksums at different period..., Prediction:  file are. the the the the the..., Forward Time: 44.99 ms, Backward Time: 105.60 ms
# Iter 142/3000000, Loss: 11.553562, Perplexity: 104147.367188, Chunk Size: 8, Batch Size: 1, Input:  size –checksums at different period of..., Target:  –checksums at different period of times..., Prediction: . the the the the the the the..., Forward Time: 44.86 ms, Backward Time: 105.85 ms
# Iter 143/3000000, Loss: 9.906103, Perplexity: 20052.380859, Chunk Size: 8, Batch Size: 1, Input: checksums at different period of times and..., Target: ums at different period of times and a..., Prediction:  the the the the the the the the..., Forward Time: 42.65 ms, Backward Time: 106.12 ms
# Iter 144/3000000, Loss: 9.434981, Perplexity: 12518.732422, Chunk Size: 8, Batch Size: 1, Input:  at different period of times and a file..., Target:  different period of times and a file bigger..., Prediction:  the the the the the the the...., Forward Time: 43.62 ms, Backward Time: 100.80 ms
# Iter 145/3000000, Loss: 8.423206, Perplexity: 4551.473633, Chunk Size: 8, Batch Size: 1, Input:  period of times and a file bigger in..., Target:  of times and a file bigger in size..., Prediction:  the the the the the. the the..., Forward Time: 40.22 ms, Backward Time: 107.76 ms
# Iter 146/3000000, Loss: 9.085315, Perplexity: 8824.742188, Chunk Size: 8, Batch Size: 1, Input:  times and a file bigger in size than..., Target:  and a file bigger in size than at..., Prediction:  and the file. the the. the..., Forward Time: 37.90 ms, Backward Time: 94.64 ms
# Iter 147/3000000, Loss: 9.387473, Perplexity: 11937.895508, Chunk Size: 8, Batch Size: 1, Input:  a file bigger in size than at a..., Target:  file bigger in size than at a previous..., Prediction:  file. the the. the of file..., Forward Time: 40.43 ms, Backward Time: 96.06 ms
# Iter 148/3000000, Loss: 9.271612, Perplexity: 10631.878906, Chunk Size: 8, Batch Size: 1, Input:  bigger in size than at a previous date..., Target:  in size than at a previous date is..., Prediction:  the the. the of file of of..., Forward Time: 37.10 ms, Backward Time: 101.47 ms
# Iter 149/3000000, Loss: 9.284449, Perplexity: 10769.233398, Chunk Size: 8, Batch Size: 1, Input:  size than at a previous date is a..., Target:  than at a previous date is a sign..., Prediction: . the of file of of of file..., Forward Time: 48.41 ms, Backward Time: 101.19 ms
# Iter 150/3000000, Loss: 8.327324, Perplexity: 4135.336426, Chunk Size: 8, Batch Size: 1, Input:  at a previous date is a sign of..., Target:  a previous date is a sign of infection..., Prediction:  a file a and of file the the..., Forward Time: 37.98 ms, Backward Time: 106.31 ms
# Iter 151/3000000, Loss: 9.219519, Perplexity: 10092.206055, Chunk Size: 8, Batch Size: 1, Input:  previous date is a sign of infection.\n..., Target:  date is a sign of infection.\nA..., Prediction:  a a of file of a aThe..., Forward Time: 43.93 ms, Backward Time: 95.10 ms
# Iter 152/3000000, Loss: 9.625066, Perplexity: 15139.549805, Chunk Size: 8, Batch Size: 1, Input:  is a sign of infection.\nA special..., Target:  a sign of infection.\nA special category..., Prediction:  a file of a aThe of of..., Forward Time: 38.33 ms, Backward Time: 122.34 ms
# Iter 153/3000000, Loss: 9.302814, Perplexity: 10968.846680, Chunk Size: 8, Batch Size: 1, Input:  sign of infection.\nA special category of..., Target:  of infection.\nA special category of viruses..., Prediction:  of a aThe a of and a..., Forward Time: 54.04 ms, Backward Time: 113.13 ms
# Iter 154/3000000, Loss: 9.725115, Perplexity: 16732.611328, Chunk Size: 8, Batch Size: 1, Input:  infection.\nA special category of viruses are..., Target: .\nA special category of viruses are “..., Prediction:  aThe a a a a a a..., Forward Time: 50.21 ms, Backward Time: 108.60 ms
# Iter 155/3000000, Loss: 10.017586, Perplexity: 22417.242188, Chunk Size: 8, Batch Size: 1, Input: A special category of viruses are “B..., Target:  special category of viruses are “Bacteria..., Prediction:  a a of a a a of a..., Forward Time: 51.95 ms, Backward Time: 111.20 ms
# Iter 156/3000000, Loss: 9.459696, Perplexity: 12831.979492, Chunk Size: 8, Batch Size: 1, Input:  category of viruses are “Bacteria”..., Target:  of viruses are “Bacteria” viruses..., Prediction:  of a a a of a of the..., Forward Time: 53.25 ms, Backward Time: 119.51 ms
# Iter 157/3000000, Loss: 10.144818, Perplexity: 25458.839844, Chunk Size: 8, Batch Size: 1, Input:  viruses are “Bacteria” viruses,..., Target:  are “Bacteria” viruses, they..., Prediction:  a a of a of the a the..., Forward Time: 46.55 ms, Backward Time: 102.14 ms
# Iter 158/3000000, Loss: 10.586313, Perplexity: 39589.261719, Chunk Size: 8, Batch Size: 1, Input:  “Bacteria” viruses, they replicate..., Target: Bacteria” viruses, they replicate themselves..., Prediction:  of a of the a a a of..., Forward Time: 42.52 ms, Backward Time: 116.98 ms
# ...
# Iter 3486/3000000, Loss: 9.666033, Perplexity: 15772.651367, Chunk Size: 8, Batch Size: 1, Input:  their lodges, hence the name "..., Target:  lodges, hence the name "l..., Prediction: ,,,,,It,,..., Forward Time: 41.58 ms, Backward Time: 121.59 ms
# Iter 3487/3000000, Loss: 9.252641, Perplexity: 10432.077148, Chunk Size: 8, Batch Size: 1, Input: ges, hence the name "lodge..., Target: , hence the name "lodgepole..., Prediction: ,ft,It,,,,..., Forward Time: 59.69 ms, Backward Time: 91.97 ms
# Iter 3488/3000000, Loss: 10.538989, Perplexity: 37759.375000, Chunk Size: 8, Batch Size: 1, Input:  hence the name "lodgepole pine..., Target:  the name "lodgepole pine."..., Prediction: ,It,,,,,,..., Forward Time: 36.95 ms, Backward Time: 96.24 ms
# Iter 3489/3000000, Loss: 10.947268, Perplexity: 56798.687500, Chunk Size: 8, Batch Size: 1, Input:  name "lodgepole pine." The..., Target:  "lodgepole pine." The indigenous..., Prediction: ,,,,,,,,..., Forward Time: 42.73 ms, Backward Time: 97.80 ms
# Iter 3490/3000000, Loss: 10.363513, Perplexity: 31682.285156, Chunk Size: 8, Batch Size: 1, Input: lodgepole pine." The indigenous peoples..., Target: odgepole pine." The indigenous peoples of..., Prediction: ,,,,,ft,,..., Forward Time: 39.91 ms, Backward Time: 99.41 ms
# Iter 3491/3000000, Loss: 9.210340, Perplexity: 9999.992188, Chunk Size: 8, Batch Size: 1, Input: pole pine." The indigenous peoples of the..., Target:  pine." The indigenous peoples of the Pacific..., Prediction: ,,,ft,,ftft..., Forward Time: 37.61 ms, Backward Time: 137.38 ms
# Iter 3492/3000000, Loss: 8.907788, Perplexity: 7389.299805, Chunk Size: 8, Batch Size: 1, Input: ." The indigenous peoples of the Pacific Northwest..., Target:  The indigenous peoples of the Pacific Northwest a..., Prediction: , - -,ftft,,..., Forward Time: 46.12 ms, Backward Time: 110.95 ms
# Iter 3493/3000000, Loss: 8.114079, Perplexity: 3341.177490, Chunk Size: 8, Batch Size: 1, Input:  indigenous peoples of the Pacific Northwest and o..., Target:  peoples of the Pacific Northwest and of Californi..., Prediction:  -, -It,, - -..., Forward Time: 59.36 ms, Backward Time: 116.22 ms
# Iter 3494/3000000, Loss: 6.728029, Perplexity: 835.498657, Chunk Size: 8, Batch Size: 1, Input:  of the Pacific Northwest and of California also..., Target:  the Pacific Northwest and of California also used..., Prediction:  -It,, - -, -..., Forward Time: 36.60 ms, Backward Time: 94.09 ms
# Iter 3495/3000000, Loss: 8.367561, Perplexity: 4305.124512, Chunk Size: 8, Batch Size: 1, Input:  Pacific Northwest and of California also used dif..., Target:  Northwest and of California also used different p..., Prediction:  to to -ing toing to,..., Forward Time: 38.37 ms, Backward Time: 110.16 ms
# Iter 3496/3000000, Loss: 6.630942, Perplexity: 758.196289, Chunk Size: 8, Batch Size: 1, Input:  and of California also used different parts of..., Target:  of California also used different parts of the..., Prediction:  the the to the to the to the..., Forward Time: 38.56 ms, Backward Time: 90.17 ms
# Iter 3497/3000000, Loss: 8.820323, Perplexity: 6770.451172, Chunk Size: 8, Batch Size: 1, Input:  California also used different parts of the plant..., Target:  also used different parts of the plant internally..., Prediction:  to the to the to the the to..., Forward Time: 45.63 ms, Backward Time: 128.75 ms
# Iter 3498/3000000, Loss: 9.596905, Perplexity: 14719.152344, Chunk Size: 8, Batch Size: 1, Input:  used different parts of the plant internally and..., Target:  different parts of the plant internally and exter..., Prediction:  to the to the the to to the..., Forward Time: 69.34 ms, Backward Time: 90.64 ms
# Iter 3499/3000000, Loss: 7.153675, Perplexity: 1278.796997, Chunk Size: 8, Batch Size: 1, Input:  parts of the plant internally and externally as..., Target:  of the plant internally and externally as a..., Prediction:  of the the of of the of the..., Forward Time: 56.74 ms, Backward Time: 122.45 ms
# Iter 3500/3000000, Loss: 10.056441, Perplexity: 23305.421875, Chunk Size: 8, Batch Size: 1, Input:  the plant internally and externally as a traditio..., Target:  plant internally and externally as a traditional ..., Prediction:  the of of the of the the the..., Forward Time: 47.76 ms, Backward Time: 107.04 ms
# Iter 3501/3000000, Loss: 8.935644, Perplexity: 7598.029297, Chunk Size: 8, Batch Size: 1, Input:  internally and externally as a traditional medici..., Target:  and externally as a traditional medicine for vari..., Prediction:  of the of the the the of the..., Forward Time: 48.42 ms, Backward Time: 109.79 ms
# Iter 3502/3000000, Loss: 9.980747, Perplexity: 21606.451172, Chunk Size: 8, Batch Size: 1, Input:  externally as a traditional medicine for various ..., Target:  as a traditional medicine for various ailments.Th..., Prediction:  of the the of of of of of..., Forward Time: 42.80 ms, Backward Time: 108.62 ms
# Iter 3503/3000000, Loss: 10.178023, Perplexity: 26318.394531, Chunk Size: 8, Batch Size: 1, Input:  a traditional medicine for various ailments.The g..., Target:  traditional medicine for various ailments.The gum..., Prediction:  of of of of of of of of..., Forward Time: 39.72 ms, Backward Time: 115.14 ms
# Iter 3504/3000000, Loss: 9.269328, Perplexity: 10607.623047, Chunk Size: 8, Batch Size: 1, Input:  medicine for various ailments.The gum of shore..., Target:  for various ailments.The gum of shore pine..., Prediction:  of The of of of of of of..., Forward Time: 60.86 ms, Backward Time: 91.05 ms
# Iter 3505/3000000, Loss: 8.506495, Perplexity: 4946.791504, Chunk Size: 8, Batch Size: 1, Input:  various ailments.The gum of shore pine was..., Target:  ailments.The gum of shore pine was used..., Prediction:  The The The The The The The The..., Forward Time: 65.73 ms, Backward Time: 110.24 ms
# Iter 3506/3000000, Loss: 8.748974, Perplexity: 6304.215820, Chunk Size: 8, Batch Size: 1, Input: .The gum of shore pine was used medicinal..., Target:  gum of shore pine was used medicinally..., Prediction:  The The The The The The of The..., Forward Time: 44.40 ms, Backward Time: 109.32 ms
# Iter 3507/3000000, Loss: 8.316654, Perplexity: 4091.448242, Chunk Size: 8, Batch Size: 1, Input:  of shore pine was used medicinally as..., Target:  shore pine was used medicinally as well..., Prediction:  The The The The of of of The..., Forward Time: 44.60 ms, Backward Time: 117.57 ms
# Iter 3508/3000000, Loss: 7.252390, Perplexity: 1411.474854, Chunk Size: 8, Batch Size: 1, Input:  pine was used medicinally as well as..., Target:  was used medicinally as well as for..., Prediction:  of The of of of The The The..., Forward Time: 48.19 ms, Backward Time: 112.17 ms
# Iter 3509/3000000, Loss: 7.835882, Perplexity: 2529.765137, Chunk Size: 8, Batch Size: 1, Input:  used medicinally as well as for chewing..., Target:  medicinally as well as for chewing...., Prediction:  of of of of of of pine of..., Forward Time: 41.95 ms, Backward Time: 89.23 ms
# Iter 3510/3000000, Loss: 5.731401, Perplexity: 308.401031, Chunk Size: 8, Batch Size: 1, Input: ly as well as for chewing. Native..., Target:  as well as for chewing. Native Americans..., Prediction:  of as as as of of pine of..., Forward Time: 63.71 ms, Backward Time: 92.35 ms
# Iter 3511/3000000, Loss: 7.007611, Perplexity: 1105.011841, Chunk Size: 8, Batch Size: 1, Input:  well as for chewing. Native Americans consumed..., Target:  as for chewing. Native Americans consumed the..., Prediction:  as as as as as as as as..., Forward Time: 41.98 ms, Backward Time: 95.27 ms
# Iter 3512/3000000, Loss: 9.982745, Perplexity: 21649.664062, Chunk Size: 8, Batch Size: 1, Input:  for chewing. Native Americans consumed the inner..., Target:  chewing. Native Americans consumed the inner bark..., Prediction:  as as as as as as as as..., Forward Time: 45.74 ms, Backward Time: 92.06 ms
# Iter 3513/3000000, Loss: 9.389549, Perplexity: 11962.705078, Chunk Size: 8, Batch Size: 1, Input: . Native Americans consumed the inner bark of..., Target:  Native Americans consumed the inner bark of lodge..., Prediction:  as as as as as as as as..., Forward Time: 47.36 ms, Backward Time: 99.86 ms
# Iter 3514/3000000, Loss: 8.766629, Perplexity: 6416.507324, Chunk Size: 8, Batch Size: 1, Input:  Americans consumed the inner bark of lodgepole..., Target:  consumed the inner bark of lodgepole pine..., Prediction:  as as as as as as as as..., Forward Time: 41.68 ms, Backward Time: 126.33 ms
# Iter 3515/3000000, Loss: 8.911446, Perplexity: 7416.374512, Chunk Size: 8, Batch Size: 1, Input:  the inner bark of lodgepole pine to..., Target:  inner bark of lodgepole pine to prevent..., Prediction:  pine as as as as as as as..., Forward Time: 38.86 ms, Backward Time: 159.94 ms
# Iter 3516/3000000, Loss: 7.591209, Perplexity: 1980.706543, Chunk Size: 8, Batch Size: 1, Input:  bark of lodgepole pine to prevent starvation..., Target:  of lodgepole pine to prevent starvation for..., Prediction:  for for for for for Native for for..., Forward Time: 39.25 ms, Backward Time: 128.41 ms
# Iter 3517/3000000, Loss: 7.933691, Perplexity: 2789.703369, Chunk Size: 8, Batch Size: 1, Input:  lodgepole pine to prevent starvation for themselv..., Target: pole pine to prevent starvation for themselves and..., Prediction:  for for for Native for for Americans for..., Forward Time: 39.70 ms, Backward Time: 107.81 ms
# Iter 3518/3000000, Loss: 9.469819, Perplexity: 12962.541992, Chunk Size: 8, Batch Size: 1, Input:  pine to prevent starvation for themselves and the..., Target:  to prevent starvation for themselves and their ho..., Prediction:  for Native for for Americans for Native for..., Forward Time: 47.67 ms, Backward Time: 128.89 ms
# Iter 3519/3000000, Loss: 9.329887, Perplexity: 11269.862305, Chunk Size: 8, Batch Size: 1, Input:  prevent starvation for themselves and their horse..., Target:  starvation for themselves and their horses\nSee..., Prediction:  for for Americans for Native for for Americans..., Forward Time: 38.06 ms, Backward Time: 110.51 ms
# Iter 3520/3000000, Loss: 9.495348, Perplexity: 13297.721680, Chunk Size: 8, Batch Size: 1, Input:  for themselves and their horses\nSee the..., Target:  themselves and their horses\nSee the photo..., Prediction:  for for Native for for for for Native..., Forward Time: 39.02 ms, Backward Time: 116.05 ms
# Iter 3521/3000000, Loss: 9.103145, Perplexity: 8983.498047, Chunk Size: 8, Batch Size: 1, Input:  and their horses\nSee the photo at..., Target:  their horses\nSee the photo at right..., Prediction:  for for for for for Native for for..., Forward Time: 37.95 ms, Backward Time: 96.13 ms
# Total Iterations: 3522/3000000 | Loss: 8.92103
# Iter 3522/3000000, Loss: 6.450990, Perplexity: 633.328796, Chunk Size: 16, Batch Size: 1, Input: The Lodge Pole Pine Christmas tree is a native to ..., Target:  Lodge Pole Pine Christmas tree is a native to the..., Prediction:  and the and for the for and for and the the for f..., Forward Time: 63.29 ms, Backward Time: 150.63 ms
# Iter 3523/3000000, Loss: 5.055448, Perplexity: 156.874725, Chunk Size: 16, Batch Size: 1, Input:  Christmas tree is a native to the Rocky Mountains..., Target:  tree is a native to the Rocky Mountains in the we..., Prediction: . the used for for for used for to the pine for fo..., Forward Time: 54.43 ms, Backward Time: 162.65 ms
# Iter 3524/3000000, Loss: 5.050428, Perplexity: 156.089233, Chunk Size: 16, Batch Size: 1, Input:  native to the Rocky Mountains in the western in t..., Target:  to the Rocky Mountains in the western in the west..., Prediction:  and the a and the the and for to the and and the ..., Forward Time: 60.12 ms, Backward Time: 125.73 ms
# Iter 3525/3000000, Loss: 5.386520, Perplexity: 218.441864, Chunk Size: 16, Batch Size: 1, Input:  Mountains in the western in the western United St..., Target:  in the western in the western United States.\nHow..., Prediction:  and the a pine the the pine and to the pine in th..., Forward Time: 62.47 ms, Backward Time: 146.09 ms
# Iter 3526/3000000, Loss: 5.839813, Perplexity: 343.715149, Chunk Size: 16, Batch Size: 1, Input:  in the western United States.\nHowever, the Lodge..., Target:  the western United States.\nHowever, the Lodgepol..., Prediction:  and the treepole the the pine in to thepole in th..., Forward Time: 77.21 ms, Backward Time: 122.11 ms
# Iter 3527/3000000, Loss: 5.199010, Perplexity: 181.092850, Chunk Size: 16, Batch Size: 1, Input:  States.\nHowever, the Lodgepole found greater pop..., Target: .\nHowever, the Lodgepole found greater popularity..., Prediction:  in thepolepole the thepole in thepolepole in thep..., Forward Time: 49.47 ms, Backward Time: 144.11 ms
# Iter 3528/3000000, Loss: 4.224171, Perplexity: 68.317818, Chunk Size: 16, Batch Size: 1, Input:  the Lodgepole found greater popularity in the UK ..., Target:  Lodgepole found greater popularity in the UK as a..., Prediction:  inpole Unitedpole inpolepolepole thepolepolepole ..., Forward Time: 67.18 ms, Backward Time: 129.37 ms
# ^C
# Traceback (most recent call last):
#   File "/mnt/e/jupyter/milklm/code02/train.py", line 108, in <module>
#     main()
#   File "/mnt/e/jupyter/milklm/code02/train.py", line 105, in main
#     train(model, buffer_loader, optimizer, scheduler, criterion, device, model_config, train_config, data_config, max_batch_sizes)
#   File "/mnt/e/jupyter/milklm/code02/train.py", line 61, in train
#     train_loss, total_iters = train_iter(model, chunk_loader, optimizer, scheduler, criterion, device, total_iters, max_total_iters, model_config, train_config, data_config, tokenizer)
#   File "/mnt/e/jupyter/milklm/code02/train.py", line 25, in train_iter
#     logits, loss = model(inputs, targets)
#   File "/home/ubuntu/miniconda3/envs/gguf/lib/python3.9/site-packages/torch/nn/modules/module.py", line 1532, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/ubuntu/miniconda3/envs/gguf/lib/python3.9/site-packages/torch/nn/modules/module.py", line 1541, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/mnt/e/jupyter/milklm/code02/model.py", line 37, in forward
#     x = block(x)
#   File "/home/ubuntu/miniconda3/envs/gguf/lib/python3.9/site-packages/torch/nn/modules/module.py", line 1532, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/ubuntu/miniconda3/envs/gguf/lib/python3.9/site-packages/torch/nn/modules/module.py", line 1541, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/mnt/e/jupyter/milklm/code02/modules.py", line 227, in forward
#     x = x + checkpoint(self.attn, self.ln_1(x))
#   File "/home/ubuntu/miniconda3/envs/gguf/lib/python3.9/site-packages/torch/_compile.py", line 24, in inner
#     return torch._dynamo.disable(fn, recursive)(*args, **kwargs)
#   File "/home/ubuntu/miniconda3/envs/gguf/lib/python3.9/site-packages/torch/_dynamo/eval_frame.py", line 451, in _fn
#     return fn(*args, **kwargs)
#   File "/home/ubuntu/miniconda3/envs/gguf/lib/python3.9/site-packages/torch/_dynamo/external_utils.py", line 36, in inner
#     return fn(*args, **kwargs)
#   File "/home/ubuntu/miniconda3/envs/gguf/lib/python3.9/site-packages/torch/utils/checkpoint.py", line 487, in checkpoint
#     return CheckpointFunction.apply(function, preserve, *args)
#   File "/home/ubuntu/miniconda3/envs/gguf/lib/python3.9/site-packages/torch/autograd/function.py", line 598, in apply
#     return super().apply(*args, **kwargs)  # type: ignore[misc]
#   File "/home/ubuntu/miniconda3/envs/gguf/lib/python3.9/site-packages/torch/utils/checkpoint.py", line 262, in forward
#     outputs = run_function(*args)
#   File "/home/ubuntu/miniconda3/envs/gguf/lib/python3.9/site-packages/torch/nn/modules/module.py", line 1532, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/ubuntu/miniconda3/envs/gguf/lib/python3.9/site-packages/torch/nn/modules/module.py", line 1541, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/mnt/e/jupyter/milklm/code02/modules.py", line 144, in forward
#     k_se_body = self._project_tokens(k, tokens_body_chunk)
# KeyboardInterrupt

# %%
Iter 487/3000000, Loss: 8.020070, Perplexity: 3041.390381, Chunk Size: 8, Batch Size: 1, Input: ” or “registry cleaners” or visiting..., Target:  or “registry cleaners” or visiting malicious..., Prediction:  by by by by by by by by..., Forward Time: 41.12 ms, Backward Time: 99.67 ms
Iter 488/3000000, Loss: 10.079155, Perplexity: 23840.832031, Chunk Size: 8, Batch Size: 1, Input:  “registry cleaners” or visiting malicious sites..., Target: registry cleaners” or visiting malicious sites t..., Prediction:  by by by or by by by by..., Forward Time: 49.27 ms, Backward Time: 94.55 ms
Total Iterations: 489/3000000 | Loss: 9.22127
Traceback (most recent call last):
  File "/mnt/e/jupyter/milklm/code02/train.py", line 108, in <module>
    main()
  File "/mnt/e/jupyter/milklm/code02/train.py", line 105, in main
    train(model, buffer_loader, optimizer, scheduler, criterion, device, model_config, train_config, data_config, max_batch_sizes)
  File "/mnt/e/jupyter/milklm/code02/train.py", line 60, in train
    chunk_loader = ChunkDataLoader(buffer, data_config, max_batch_sizes, chunk_size)
  File "/mnt/e/jupyter/milklm/code02/chunk_data_loader.py", line 20, in __init__
    self.batch_size = self.max_batch_sizes[chunk_size]
IndexError: list index out of range
